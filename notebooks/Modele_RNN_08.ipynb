# %% [markdown]
# <a href="https://colab.research.google.com/github/ManDes71/Rakuten_Text_Classification_TensorFlow/blob/main/notebooks/Modele_RNN_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Google Colab -> Cette cellule est à executer (1 fois) pour le cloner le dépot en local***
# il est possible que google colab vous demande re demarrer la session

# %%
token = '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'  # Votre token d'accès personnel
repo_url = 'https://github.com/ManDes71/Rakuten_Text_Classification_TensorFlow.git'
cloning_url = f'https://{token}:x-oauth-basic@' + repo_url.split('://')[1]
# !git clone {cloning_url}
# Out:
# Cloning into 'Rakuten_Text_Classification_TensorFlow'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 143 (delta 79), reused 42 (delta 16), pack-reused 0
# Receiving objects: 100% (143/143), 27.32 MiB | 15.51 MiB/s, done.
# Resolving deltas: 100% (79/79), done.

# %% [markdown]
# **Google Colab -> Cette cellule est à executer (2 fois) pour installer les bibliothèques nécessaires**
# You must restart the runtime in order to use newly installed versions.

# %%
import sys
sys.path.append('/content/Rakuten_Text_Classification_TensorFlow')
# !pip install -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt
# Out:
# Requirement already satisfied: joblib==1.2.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: keras==2.10.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: langdetect==1.0.7 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 3)) (1.0.7)
# Requirement already satisfied: matplotlib==3.8.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 4)) (3.8.0)
# Requirement already satisfied: nltk==3.8.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: numpy==1.26.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 6)) (1.26.3)
# Requirement already satisfied: pandas==2.1.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 7)) (2.1.4)
# Requirement already satisfied: Pillow==10.0.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 8)) (10.0.1)
# Requirement already satisfied: scikit-learn==1.3.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: scipy==1.11.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 10)) (1.11.4)
# Requirement already satisfied: tensorflow==2.10.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (2.10.0)
# Requirement already satisfied: tqdm==4.65.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 12)) (4.65.0)
# Requirement already satisfied: spacy==3.7.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (3.7.2)
# Requirement already satisfied: swifter in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (1.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect==1.0.7->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 4)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 4)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 4)) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk==3.8.1->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 5)) (2023.12.25)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 7)) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.1.4->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 7)) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 9)) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (1.60.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (3.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (3.19.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (67.7.2)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (2.10.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (0.36.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (1.14.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (6.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (3.1.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (3.3.0)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (2023.8.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (0.42.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (2023.6.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (7.0.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2024.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (3.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy==3.7.2->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 13)) (2.1.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (3.17.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[dataframe]>=2.10.0->swifter->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (3.2.2)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from keras.optimizers import SGD,Adam
from tensorflow.keras.utils import to_categorical

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, RNN, GRUCell
from tensorflow.keras.layers import  Dropout ,Conv1D,Flatten,Bidirectional,LSTM,BatchNormalization

from nltk.tokenize import PunktSentenceTokenizer
from nltk.tokenize.regexp import RegexpTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.metrics import f1_score, make_scorer,accuracy_score,classification_report
import nltk
import re

from sklearn import svm
import unicodedata
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import swifter

# Ajuster la largeur maximale des colonnes à 100 pour éviter la troncature
pd.set_option('display.max_colwidth', 100)

# set the max columns to none
pd.set_option('display.max_columns', None)

# %%
MAXLEN = 600
NUM_WORDS = 70000
EMBEDDING_DIM = 200

# %%
import configparser
import sys
#sys.path.append('../src')
sys.path.append('/content/Rakuten_Text_Classification_TensorFlow/src')
import Bibli_DataScience_3_3 as ds
config = configparser.ConfigParser()
config.read('Rakuten_config_colab.ini')
# Out:
# section :  ['DOSSIER', 'FICHIER']
# []

# %%
import pandas as pd

# lecture des données sources d'entrainement
df_feats=pd.read_csv(ds.get_RACINE_DOSSIER() + 'X_train_update.csv')

# lecture des données cibles d'entrainement
df_target=pd.read_csv(ds.get_RACINE_DOSSIER() + 'Y_train_CVw08PX.csv')


# création d'un dataframe globale -  jointure
df=df_feats.merge(df_target,on='Unnamed: 0',how='inner')
df.rename(columns={'Unnamed: 0': 'Id'}, inplace=True)

# récupération du fichier df_langue.csv
df_langue=pd.read_csv(ds.get_RACINE_DOSSIER() + 'df_langue.csv')
df=df.merge(df_langue.drop(['Unnamed: 0','prdtypecode'], axis=1),on='Id',how='inner')

Lcat=df_target.sort_values(by='prdtypecode')['prdtypecode'].unique()


nomenclature=pd.read_csv(ds.get_RACINE_DOSSIER() + 'NOMENCLATURE.csv',header=0,encoding='utf-8',sep=';',index_col=0)
catdict=nomenclature.to_dict()['definition']

#
stopwordFR = pd.read_csv(ds.get_RACINE_DOSSIER() + 'stopwords_FR_02.csv')
stop_words = stopwordFR['MOT'].tolist()
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df_feats
# Out:
#        Unnamed: 0  \
# 0               0
# 1               1
# 2               2
# 3               3
# 4               4
# ...           ...
# 84911       84911
# 84912       84912
# 84913       84913
# 84914       84914
# 84915       84915
#
#                                                                                                designation  \
# 0                 Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
# 1      Journal Des Arts (Le) N° 133 Du 28/09/2001 - L'art Et Son Marche Salon D'art Asiatique A Paris -...
# 2                             Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style
# 3                                          Peluche Donald - Europe - Disneyland 2000 (Marionnette À Doigt)
# 4                                                                                     La Guerre Des Tuques
# ...                                                                                                    ...
# 84911                                                                          The Sims [ Import Anglais ]
# 84912                                                 Kit piscine acier NEVADA déco pierre Ø 3.50m x 0.90m
# 84913  Journal Officiel De La Republique Francaise N° 46 Du 15/02/1871 - Changement D'adresses - Partie...
# 84914                                      Table Basse Bois De Récupération Massif Base Blanche 60x60x33cm
# 84915                                               Gomme De Collection 2 Gommes Pinguin Glace Vert Orange
#
#                                                                                                description  \
# 0                                                                                                      NaN
# 1                                                                                                      NaN
# 2      PILOT STYLE Touch Pen de marque Speedlink est 1 stylet ergonomique pour GamePad Nintendo Wii U.<...
# 3                                                                                                      NaN
# 4      Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de boules de neige et s'a...
# ...                                                                                                    ...
# 84911                                                                                                  NaN
# 84912  <b>Description complète :</b><br />Kit piscine hors-sol Toi PIEDRA GRIS ronde Ø 3.50m hauteur 0....
# 84913                                                                                                  NaN
# 84914  <p>Cette table basse a un design unique et constituera un ajout intemporel à votre maison. Son d...
# 84915                                                                                                  NaN
#
#         productid     imageid
# 0      3804725264  1263597046
# 1       436067568  1008141237
# 2       201115110   938777978
# 3        50418756   457047496
# 4       278535884  1077757786
# ...           ...         ...
# 84911   206719094   941495734
# 84912  3065095706  1188462883
# 84913   440707564  1009325617
# 84914  3942400296  1267353403
# 84915    57203227   684671297
#
# [84916 rows x 5 columns]

# %%
df_target
# Out:
#        Unnamed: 0  prdtypecode
# 0               0           10
# 1               1         2280
# 2               2           50
# 3               3         1280
# 4               4         2705
# ...           ...          ...
# 84911       84911           40
# 84912       84912         2583
# 84913       84913         2280
# 84914       84914         1560
# 84915       84915         2522
#
# [84916 rows x 2 columns]

# %%
import pandas as pd

def combine_description_and_designation(row):
    partie_design = row['designation'] if isinstance(row['designation'], str) else ''
    partie_descrip = row['description'] if isinstance(row['description'], str) else ''
    return partie_design + ' ' + partie_descrip if len(partie_descrip) > 0 else partie_design

# Appliquer la fonction à chaque ligne
df_feats['phrases'] = df_feats.swifter.apply(combine_description_and_designation, axis=1)
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]

# %%
print(df_feats.loc[4,['phrases']])
# Out:
# phrases    La Guerre Des Tuques Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de b...
# Name: 4, dtype: object

# %% [markdown]
# https://blog.coddity.com/articles/natural-language-processing/

# %% [markdown]
# # ETAPE 1 :
# ## Passage en minuscule
# Dans un premier temps, nous transformons les majuscules en minuscules car les étapes suivantes sont sensibles à la casse
# ## ETAPE 2: Tokenisation
#  Il s’agit de décomposer une phrase, et donc un document, en tokens. Un token est un élément correspondant à un mot ou une ponctuation, cependant de nombreux cas ne sont pas triviaux à traiter :
# Les mots avec un trait d’union, exemple : peut être et peut-être qui ont des significations très différentes ;
# Les dates et heures qui peuvent être séparées par des points, des slashs, des deux points ;
# Les apostrophes ;
# Les caractères spéciaux : émoticônes, formules mathématiques.

# %%
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

def preprocess_sentence(w):
    w = str(w)
    # Remplacer les entités HTML par des caractères spécifiques ou les supprimer
    replacements = {
        '&eacute;': 'e',
        '&amp;': '',    # Esperluette
        '&lt;': '',     # Inférieur à
        '&gt;': '',     # Supérieur à
        '&quot;': '',   # Guillemet double
        '&apos;': '',   # Apostrophe
        '&nbsp;': '',   # Espace insécable
        '&copy;': '',   # Droit d'auteur
        '&reg;': '',    # Marque déposée
        '&euro;': '',   # Symbole de l'euro
        '&rsquo;': '',
        '&agrave;': 'a',
        '&ccedil;': 'c',
        '&egrave;': 'e',
        '&iacute;': 'i',
        '&ntilde;': 'n',
        '&ouml;': 'o',
    }
    for entity, replacement in replacements.items():
        w = w.replace(entity, replacement)
    w = unicode_to_ascii(w.lower().strip())
    w = w.replace("n°", "??numero??")
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    w = re.sub(r"[^a-zA-Z?.!°]+", " ", w)
    w = re.sub(r'\b\w{0,2}\b', '', w)
    w = w.replace("? ? numero ? ?", "n°")


    # Suppression des stopwords
    mots = word_tokenize(w.strip())
    mots = [mot for mot in mots if mot not in stop_words]
    return ' '.join(mots).strip()

df_feats['WordRNN'] = df_feats['phrases'].swifter.apply(lambda x :preprocess_sentence(x))
df_feats.head()
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                            designation  \
# 0             Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L'art Et Son Marche Salon D'art Asiatique A Paris -...
# 2                         Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style
# 3                                      Peluche Donald - Europe - Disneyland 2000 (Marionnette À Doigt)
# 4                                                                                 La Guerre Des Tuques
#
#                                                                                            description  \
# 0                                                                                                  NaN
# 1                                                                                                  NaN
# 2  PILOT STYLE Touch Pen de marque Speedlink est 1 stylet ergonomique pour GamePad Nintendo Wii U.<...
# 3                                                                                                  NaN
# 4  Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de boules de neige et s'a...
#
#     productid     imageid  \
# 0  3804725264  1263597046
# 1   436067568  1008141237
# 2   201115110   938777978
# 3    50418756   457047496
# 4   278535884  1077757786
#
#                                                                                                phrases  \
# 0             Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L'art Et Son Marche Salon D'art Asiatique A Paris -...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style PILOT STYLE Touch P...
# 3                                      Peluche Donald - Europe - Disneyland 2000 (Marionnette À Doigt)
# 4  La Guerre Des Tuques Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de b...
#
#                                                                                                WordRNN
# 0                                olivia personalisiertes notizbuch seiten punktraster din rosen design
# 1  journal arts n° art marche salon art asiatique paris jacques barrere francois perrier reforme ve...
# 2  grand stylet ergonomique bleu gamepad nintendo wii speedlink pilot style pilot style touch pen m...
# 3                                                   peluche donald europe disneyland marionnette doigt
# 4  guerre tuques luc idees grandeur . veut organiser jeu guerre boules neige arranger vainqueur inc...

# %% [markdown]
# ## ETAPE 3: Retrait des stopwords
# Ensuite, nous retirons les mots appartenant aux stopwords. Il s’agit de listes de mots définies au préalable soit par l’utilisateur soit dans des librairies existantes. Ces listes se composent de mots qui n’apportent aucune information, qui sont en général très courants et donc présents dans la plupart des documents, par exemple : je, nous, avoir (le verbe et ses conjugaisons). La suppression de ces stopwords permet de ne pas polluer les représentations des documents afin qu’elle ne contienne que les mots représentatifs et significatifs. Ce “nettoyage” du texte peut aussi s’accompagner de la suppression d’autres éléments comme les nombres, les dates, la ponctuation etc.

# %%
import string
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

nltk.download('punkt')
nltk.download('stopwords')

# Ajustement de la fonction preprocess_text
def preprocess_text(text):
    try:
        lang = detect(text)
    except:
        lang = "fr"  # Définit le français comme langue par défaut
    #text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Utilise le français comme langue de fallback pour la tokenisation
    tokens = word_tokenize(text, language='french' if lang not in ['en', 'es', 'de', 'nl', 'it', 'ca'] else lang)
    # Définit le français comme langue de fallback pour les stop words
    stop_words = set(stopwords.words({
        'en': 'english',
        'es': 'spanish',
        'de': 'german',
        'nl': 'dutch',
        'it': 'italian',
        'ca': 'french',  # Utilise explicitement le français pour le catalan
        'fr': 'french'
    }.get(lang, 'french')))  # Fallback sur le français pour toute autre langue non spécifiée

    tokens = [word for word in tokens if word not in stop_words]
    return tokens

# Supposons df_feats est votre DataFrame et 'concatenated' la colonne à traiter
# Appliquer preprocess_text à chaque valeur de la colonne 'concatenated'
df_feats['tokenized'] = df_feats['WordRNN'].swifter.apply(preprocess_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]

# %% [markdown]
# ## ETAPE 4 : Groupement sémantique
# Dès lors, nous disposons pour chaque document d’une liste “nettoyée” de mots porteurs de sens et séparés en tokens. Mais un mot peut être écrit au pluriel, au singulier ou avec différents accords et les verbes peuvent être conjugués à différents temps et personnes.
# Nous devons donc réduire les différences grammaticales des mots en trouvant des formes communes. Pour ce faire, nous disposons de deux méthodes distinctes :
# La stemmatisation, qui ne prend pas en compte le contexte de la phrase
# La lemmatisation, qui prend en compte le contexte
# ### ETAPE 4.1 : La stemmatisation
# La stemmatisation (ou racinisation) réduit les mots à leur radical ou racine.

# %%
X_text_train, X_text_test, y_train, y_test = train_test_split(df_feats.tokenized, df_target.prdtypecode, test_size=0.2, random_state=1234)

# %%
from nltk.stem.snowball import SnowballStemmer
def preprocess_text(tokens):
    # Détection de la langue
    try:
        lang = detect(' '.join(tokens))
    except:
        lang = "fr"  # Langue par défaut
    # Adaptation des ressources linguistiques en fonction de la langue détectée
    if lang == 'en':
        stop_words = set(stopwords.words('english'))
        stemmer = SnowballStemmer("english")
    elif lang == 'es':
        stop_words = set(stopwords.words('spanish'))
        stemmer = SnowballStemmer("spanish")
    elif lang == 'de':
        stop_words = set(stopwords.words('german'))
        stemmer = SnowballStemmer("german")
    elif lang == 'nl':
        stop_words = set(stopwords.words('dutch'))
        stemmer = SnowballStemmer("dutch")
    elif lang == 'it':
        stop_words = set(stopwords.words('italian'))
        stemmer = SnowballStemmer("italian")
    elif lang == 'ca':
        stop_words = set(stopwords.words('french'))
        stemmer = SnowballStemmer("french")
    else:
        stop_words = set(stopwords.words('french'))
        stemmer = SnowballStemmer("french")


    preprocessed_tokens = []
    for token in tokens:
        # Conversion en minuscules et suppression de la ponctuation
        token = token.lower()
        token = token.translate(str.maketrans('', '', string.punctuation))
        # Stemming et suppression des stopwords
        if token not in stop_words and token != '':
            stemmed_token = stemmer.stem(token)
            preprocessed_tokens.append(stemmed_token)

    return preprocessed_tokens

# %% [markdown]
# ### ETAPE 5 : Word Embedding
#  Le word embedding (plongement de mots) désigne un ensemble de méthode d’apprentissage visant à représenter les mots d’un texte par des vecteurs de nombres réels.
#  le word embedding est capable en réduisant la dimension de capturer le contexte, la similarité sémantique et syntaxique (genre, synonymes, …) d’un mot. Par exemple, on pourrait s’attendre à ce que les mots « chien » et « chat » soient représentés par des vecteurs relativement peu distants dans l’espace vectoriel où sont définis ces vecteurs.
#
# Comme pour les images, nous souhaitons que ça soit le modèle qui choisisse les caractéristiques les plus pertinentes représentant le mot. Par exemple, la caractéristique « être vivant » pourrait être intéressante pour différencier « chien » et « ordinateur », et rapprocher « chien » et « chat ».

# %%
# Application de la fonction de prétraitement adaptée
X_text_train_preprocessed = [preprocess_text(tokens) for tokens in X_text_train]
X_text_test_preprocessed = [preprocess_text(tokens) for tokens in X_text_test]

# Puis, continuez avec la tokenisation (dans ce cas, la re-tokenisation) et le padding
tokenizer = Tokenizer()
tokenizer.fit_on_texts([' '.join(tokens) for tokens in X_text_train_preprocessed])


X_train = tokenizer.texts_to_sequences([' '.join(tokens) for tokens in X_text_train_preprocessed])
X_test = tokenizer.texts_to_sequences([' '.join(tokens) for tokens in X_text_test_preprocessed])


X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, maxlen=MAXLEN, padding='post', truncating='post')
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, maxlen=MAXLEN, padding='post', truncating='post')

# Padding des séquences
#max_length = max(len(sequence) for sequence in sequences)
#padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# Vous pouvez ensuite attacher ces séquences paddées à votre DataFrame si nécessaire
# Par exemple, en tant que nouvelle colonne si cela a du sens pour votre application
#df_feats['padded_sequences'] = list(padded_sequences)

print("Séquences tokenisées, stemmées et paddées :")
# Out:
# Séquences tokenisées, stemmées et paddées :

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
label_encoder = LabelEncoder()
y_classes_converted = label_encoder.fit_transform(y_train)
#y_classes_train = label_encoder.transform(y_train)
# Maintenant, utilisez to_categorical
y_train_Network = to_categorical(y_classes_converted)
y_classes_converted = label_encoder.transform(y_test)
#y_classes_test = label_encoder.transform(y_test)
# Maintenant, utilisez to_categorical
y_test_Network = to_categorical(y_classes_converted)
print(y_train_Network.shape)
print(y_test_Network.shape)
# Out:
# (67932, 27)
# (16984, 27)

# %%
from tensorflow.keras.layers import  Dropout ,Conv1D,Flatten,Bidirectional,LSTM,BatchNormalization

# %%
vocab_size = len(tokenizer.word_index) + 1  # Taille du vocabulaire
embedding_dim = EMBEDDING_DIM  # Dimension de l'espace d'embedding
max_length = MAXLEN  # Déjà calculé lors du prétraitement
num_categories = 27  # Nombre de catégories

model = Sequential()
model.add(Embedding(vocab_size, EMBEDDING_DIM))
model.add(RNN(GRUCell(128), return_sequences=True))
model.add(Dropout(0.3))
model.add(GlobalAveragePooling1D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(27, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 200)         16817800
#
#  rnn_1 (RNN)                 (None, None, 128)         126720
#
#  dropout_2 (Dropout)         (None, None, 128)         0
#
#  global_average_pooling1d_1   (None, 128)              0
#  (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 27)                6939
#
# =================================================================
# Total params: 16,984,483
# Trainable params: 16,984,483
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import callbacks
lr_plateau = callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                            patience=4,
                            factor=0.5,
                            verbose=1,
                            mode='min')

# %%
model.compile(optimizer=Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
"""
model = Sequential()
model.add(Embedding(vocab_size,embedding_dim,input_length=max_length))
model.add(Conv1D(filters=32, kernel_size=8, activation='relu'))
model.add(GlobalAveragePooling1D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
        #model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(num_categories, activation='softmax'))
model.fit(X_train, y_train_Network, epochs=10, validation_split=0.2,callbacks=[lr_plateau])  # Ajustez selon vos besoins
"""
# Out:
# Epoch 1/10
# 1699/1699 [==============================] - 74s 43ms/step - loss: 1.9918 - accuracy: 0.3916 - val_loss: 1.4346 - val_accuracy: 0.5474 - lr: 0.0010
# Epoch 2/10
# 1699/1699 [==============================] - 76s 45ms/step - loss: 1.1722 - accuracy: 0.6291 - val_loss: 1.1105 - val_accuracy: 0.6793 - lr: 0.0010
# Epoch 3/10
# 1699/1699 [==============================] - 74s 43ms/step - loss: 0.7652 - accuracy: 0.7654 - val_loss: 0.9771 - val_accuracy: 0.7223 - lr: 0.0010
# Epoch 4/10
# 1699/1699 [==============================] - 68s 40ms/step - loss: 0.5375 - accuracy: 0.8370 - val_loss: 1.0031 - val_accuracy: 0.7306 - lr: 0.0010
# Epoch 5/10
# 1699/1699 [==============================] - 61s 36ms/step - loss: 0.3962 - accuracy: 0.8831 - val_loss: 1.0542 - val_accuracy: 0.7361 - lr: 0.0010
# Epoch 6/10
# 1699/1699 [==============================] - 60s 36ms/step - loss: 0.2983 - accuracy: 0.9132 - val_loss: 1.1400 - val_accuracy: 0.7365 - lr: 0.0010
# Epoch 7/10
# 1698/1699 [============================>.] - ETA: 0s - loss: 0.2330 - accuracy: 0.9338
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1699/1699 [==============================] - 64s 38ms/step - loss: 0.2330 - accuracy: 0.9338 - val_loss: 1.2880 - val_accuracy: 0.7315 - lr: 0.0010
# Epoch 8/10
# 1699/1699 [==============================] - 63s 37ms/step - loss: 0.1653 - accuracy: 0.9552 - val_loss: 1.3335 - val_accuracy: 0.7346 - lr: 5.0000e-04
# Epoch 9/10
# 1699/1699 [==============================] - 64s 38ms/step - loss: 0.1330 - accuracy: 0.9634 - val_loss: 1.4374 - val_accuracy: 0.7345 - lr: 5.0000e-04
# Epoch 10/10
# 1699/1699 [==============================] - 63s 37ms/step - loss: 0.1167 - accuracy: 0.9681 - val_loss: 1.5808 - val_accuracy: 0.7330 - lr: 5.0000e-04

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entraînement
training_history = model.fit(X_train, y_train_Network, epochs=10, validation_split=0.2,callbacks=[lr_plateau])  # Ajustez selon vos besoins
# Évaluation
loss, accuracy = model.evaluate(X_test, y_test_Network)
print(f'Loss: {loss}, Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# 1699/1699 [==============================] - 793s 466ms/step - loss: 1.5885 - accuracy: 0.5261 - val_loss: 0.8587 - val_accuracy: 0.7415 - lr: 0.0010
# Epoch 2/10
# 1699/1699 [==============================] - 792s 466ms/step - loss: 0.6590 - accuracy: 0.8055 - val_loss: 0.7087 - val_accuracy: 0.7924 - lr: 0.0010
# Epoch 3/10
# 1699/1699 [==============================] - 792s 466ms/step - loss: 0.3729 - accuracy: 0.8866 - val_loss: 0.7254 - val_accuracy: 0.7979 - lr: 0.0010
# Epoch 4/10
# 1699/1699 [==============================] - 789s 464ms/step - loss: 0.2206 - accuracy: 0.9329 - val_loss: 0.8459 - val_accuracy: 0.7950 - lr: 0.0010
# Epoch 5/10
# 1699/1699 [==============================] - 805s 474ms/step - loss: 0.1421 - accuracy: 0.9563 - val_loss: 0.9667 - val_accuracy: 0.7915 - lr: 0.0010
# Epoch 6/10
# 1699/1699 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9680
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1699/1699 [==============================] - 787s 463ms/step - loss: 0.1012 - accuracy: 0.9680 - val_loss: 1.0736 - val_accuracy: 0.7864 - lr: 0.0010
# Epoch 7/10
# 1699/1699 [==============================] - 789s 464ms/step - loss: 0.0517 - accuracy: 0.9831 - val_loss: 1.3084 - val_accuracy: 0.7855 - lr: 5.0000e-04
# Epoch 8/10
# 1699/1699 [==============================] - 791s 466ms/step - loss: 0.0337 - accuracy: 0.9887 - val_loss: 1.4585 - val_accuracy: 0.7856 - lr: 5.0000e-04
# Epoch 9/10
# 1699/1699 [==============================] - 793s 467ms/step - loss: 0.0271 - accuracy: 0.9912 - val_loss: 1.5947 - val_accuracy: 0.7816 - lr: 5.0000e-04
# Epoch 10/10
# 1699/1699 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9926
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1699/1699 [==============================] - 789s 465ms/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 1.6859 - val_accuracy: 0.7802 - lr: 5.0000e-04
# 531/531 [==============================] - 55s 104ms/step - loss: 1.7916 - accuracy: 0.7813
# Loss: 1.7916171550750732, Accuracy: 0.7812647223472595

# %%
predictions = model.predict(X_test)
y_pred = np.argmax(predictions, axis=1)
test_pred_original=label_encoder.inverse_transform(y_pred)
test_pred_original
# Out:
# 531/531 [==============================] - 4s 7ms/step
# array([2522, 1920, 2280, ..., 2583, 1160, 2462])

# %%
train_acc = training_history.history['accuracy']
val_acc = training_history.history['val_accuracy']
tloss = training_history.history['loss']
tvalloss=training_history.history['val_loss']

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(tloss)
plt.plot(tvalloss)
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')



plt.subplot(122)
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('Model acc by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right');

# %%
y_test_original=y_test
# On évalue le niveau de précision de notre prédiction.
print("Précision de la prédiction:", accuracy_score(y_test_original, test_pred_original)*100, '%')

print("Evaluation détaillée de la Classification par RDF :\n \n" ,
      (classification_report(y_test_original, test_pred_original)))
# Out:
# Précision de la prédiction: 77.9674988224211 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.47      0.42      0.44       643
#           40       0.69      0.58      0.63       503
#           50       0.70      0.74      0.72       319
#           60       0.84      0.88      0.86       179
#         1140       0.70      0.73      0.71       545
#         1160       0.90      0.85      0.87       793
#         1180       0.51      0.55      0.53       144
#         1280       0.68      0.66      0.67      1002
#         1281       0.53      0.58      0.55       408
#         1300       0.93      0.93      0.93       993
#         1301       0.92      0.91      0.92       162
#         1302       0.75      0.79      0.77       514
#         1320       0.79      0.73      0.76       664
#         1560       0.79      0.78      0.78       993
#         1920       0.89      0.90      0.90       832
#         1940       0.85      0.72      0.78       159
#         2060       0.71      0.82      0.76       970
#         2220       0.77      0.73      0.75       190
#         2280       0.77      0.77      0.77       911
#         2403       0.72      0.68      0.70       961
#         2462       0.69      0.76      0.72       301
#         2522       0.90      0.89      0.89      1011
#         2582       0.72      0.69      0.71       533
#         2583       0.96      0.96      0.96      2083
#         2585       0.72      0.70      0.71       468
#         2705       0.60      0.70      0.64       557
#         2905       0.92      0.92      0.92       146
#
#     accuracy                           0.78     16984
#    macro avg       0.76      0.75      0.75     16984
# weighted avg       0.78      0.78      0.78     16984

# %%
print(X_text_train.info())
print( y_train.info())
print(X_text_test.info())
print( y_test.info())
# Out:
# <class 'pandas.core.series.Series'>
# Index: 67932 entries, 73797 to 58067
# Series name: tokenized
# Non-Null Count  Dtype
# --------------  -----
# 67932 non-null  object
# dtypes: object(1)
# memory usage: 1.0+ MB
# None
# <class 'pandas.core.series.Series'>
# Index: 67932 entries, 73797 to 58067
# Series name: prdtypecode
# Non-Null Count  Dtype
# --------------  -----
# 67932 non-null  int64
# dtypes: int64(1)
# memory usage: 1.0 MB
# None
# <class 'pandas.core.series.Series'>
# Index: 16984 entries, 66047 to 51817
# Series name: tokenized
# Non-Null Count  Dtype
# --------------  -----
# 16984 non-null  object
# dtypes: object(1)
# memory usage: 265.4+ KB
# None
# <class 'pandas.core.series.Series'>
# Index: 16984 entries, 66047 to 51817
# Series name: prdtypecode
# Non-Null Count  Dtype
# --------------  -----
# 16984 non-null  int64
# dtypes: int64(1)
# memory usage: 265.4 KB
# None

# %%
import pandas as pd
df_test = pd.DataFrame({'tokenized': X_text_test, 'prdtypecode': y_test})
df_test['predict']=test_pred_original
df_test.head()
# Out:
#                                                                                                  tokenized  \
# 66047  [stabilo, lot, stylos, feutre, film, ohpen, universal, indelebile, rouge, stabilo, stylo, feutre...
# 29942  [housse, fauteuil, integrale, elastique, protectrice, vert, marque, homescapes, matiere, coton, ...
# 58440                                                          [miroir, sprint, n°, campionnissimo, valet]
# 55079                                                            [brisons, glace, cold, hearted, icecrown]
# 11424  [little, prince, resine, prince, accueil, table, figurine, ornement, magideal, description, vede...
#
#        prdtypecode  predict
# 66047         2522     2522
# 29942         1920     1920
# 58440         2280     2280
# 55079         1160     1281
# 11424         2060     2060

# %%
for c in Lcat:
    print(c,'   ------   ', catdict[c] )
    print(df_test[df_test['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 10    ------    livres
# predict
# 10      0.424572
# 2705    0.150855
# 2403    0.127527
# 2280    0.097978
# 40      0.037325
# Name: proportion, dtype: float64
# 40    ------    jeux video pour pc et consoles
# predict
# 40      0.582505
# 2462    0.055666
# 2705    0.047714
# 1281    0.043738
# 10      0.043738
# Name: proportion, dtype: float64
# 50    ------     accesoires jeux video
# predict
# 50      0.739812
# 2462    0.043887
# 40      0.040752
# 60      0.040752
# 1302    0.018809
# Name: proportion, dtype: float64
# 60    ------    consoles de jeux video
# predict
# 60      0.877095
# 2462    0.055866
# 50      0.022346
# 1140    0.016760
# 40      0.016760
# Name: proportion, dtype: float64
# 1140    ------    produits derives “geeks” et figurines
# predict
# 1140    0.728440
# 1280    0.088073
# 40      0.020183
# 10      0.016514
# 1180    0.014679
# Name: proportion, dtype: float64
# 1160    ------    cartes collectionables
# predict
# 1160    0.851198
# 1140    0.027743
# 10      0.025221
# 2705    0.011349
# 2280    0.011349
# Name: proportion, dtype: float64
# 1180    ------    figurines collectionables pour jeux de societe
# predict
# 1180    0.548611
# 1281    0.083333
# 1140    0.076389
# 1280    0.034722
# 2705    0.034722
# Name: proportion, dtype: float64
# 1280    ------    jouets, peluches, poupees
# predict
# 1280    0.657685
# 1281    0.091816
# 1140    0.045908
# 1320    0.027944
# 1300    0.026946
# Name: proportion, dtype: float64
# 1281    ------    jeux de societe/cartes
# predict
# 1281    0.578431
# 1280    0.164216
# 1180    0.031863
# 40      0.029412
# 2705    0.029412
# Name: proportion, dtype: float64
# 1300    ------    Petites voitures (jouets) et maquettes
# predict
# 1300    0.933535
# 1280    0.021148
# 1140    0.005035
# 2280    0.005035
# 10      0.005035
# Name: proportion, dtype: float64
# 1301    ------    accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
# predict
# 1301    0.913580
# 1281    0.030864
# 1302    0.018519
# 1320    0.012346
# 1140    0.006173
# Name: proportion, dtype: float64
# 1302    ------    jeux d'exterieur
# predict
# 1302    0.787938
# 1280    0.071984
# 2583    0.021401
# 2582    0.019455
# 1320    0.015564
# Name: proportion, dtype: float64
# 1320    ------    sacs pour femmes et accesore petite enfance
# predict
# 1320    0.733434
# 2060    0.051205
# 1280    0.049699
# 1560    0.027108
# 1920    0.019578
# Name: proportion, dtype: float64
# 1560    ------    Mobilier et produits decoration/rangement pour la maison
# predict
# 1560    0.775428
# 2060    0.085599
# 2582    0.038268
# 1920    0.026183
# 1320    0.019134
# Name: proportion, dtype: float64
# 1920    ------    linge de maison (cousins, rideaux, serviettes, nappes, draps)
# predict
# 1920    0.903846
# 2060    0.039663
# 1560    0.028846
# 1320    0.010817
# 2582    0.003606
# Name: proportion, dtype: float64
# 1940    ------    nouriture (cafes,infusions,conserves, epices,etc)
# predict
# 1940    0.716981
# 1560    0.031447
# 2522    0.031447
# 2280    0.031447
# 2060    0.025157
# Name: proportion, dtype: float64
# 2060    ------    lampes et accesoires decoration pour maison
# predict
# 2060    0.815464
# 1560    0.048454
# 1920    0.024742
# 2582    0.022680
# 2585    0.013402
# Name: proportion, dtype: float64
# 2220    ------    accesoires mascots/pets
# predict
# 2220    0.726316
# 2585    0.052632
# 2060    0.042105
# 1920    0.026316
# 1320    0.021053
# Name: proportion, dtype: float64
# 2280    ------    magazines
# predict
# 2280    0.771679
# 2403    0.096597
# 10      0.055982
# 2705    0.025247
# 1140    0.009879
# Name: proportion, dtype: float64
# 2403    ------    livres et bds
# predict
# 2403    0.682622
# 10      0.093652
# 2280    0.081165
# 2705    0.047867
# 1140    0.014568
# Name: proportion, dtype: float64
# 2462    ------    consoles de jeux video et jeux videos
# predict
# 2462    0.757475
# 50      0.106312
# 40      0.046512
# 1140    0.016611
# 60      0.016611
# Name: proportion, dtype: float64
# 2522    ------    produits de papeterie et rangement bureau
# predict
# 2522    0.889219
# 2403    0.016815
# 2060    0.015826
# 1560    0.011869
# 1280    0.011869
# Name: proportion, dtype: float64
# 2582    ------    mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# predict
# 2582    0.686679
# 1560    0.093809
# 2060    0.078799
# 2585    0.043152
# 2583    0.022514
# Name: proportion, dtype: float64
# 2583    ------    accesoires de piscine
# predict
# 2583    0.961114
# 1302    0.010082
# 2060    0.006721
# 2585    0.006241
# 2582    0.004801
# Name: proportion, dtype: float64
# 2585    ------    outillage et accesoires pour jardinage
# predict
# 2585    0.698718
# 2582    0.066239
# 2060    0.044872
# 1560    0.036325
# 2583    0.029915
# Name: proportion, dtype: float64
# 2705    ------    bds et livres
# predict
# 2705    0.698384
# 10      0.122083
# 2403    0.050269
# 2280    0.021544
# 40      0.014363
# Name: proportion, dtype: float64
# 2905    ------    Jeu En téléchargement
# predict
# 2905    0.924658
# 2705    0.027397
# 1281    0.020548
# 60      0.006849
# 1180    0.006849
# Name: proportion, dtype: float64

# %%
top5_df = pd.DataFrame({'prdtypecode':y_test_original ,'predict': test_pred_original})

df_cross=pd.crosstab(top5_df['prdtypecode'], top5_df['predict'],normalize='index')
top5_df.head()
# Out:
#        prdtypecode  predict
# 66047         2522     2522
# 29942         1920     1920
# 58440         2280     2280
# 55079         1160     1281
# 11424         2060     2060

# %%
df_pred = pd.DataFrame()
for c in Lcat:
            s = df_cross.loc[c].sort_values(ascending=False)[:5]
            df_temp = pd.DataFrame([{'Categorie':c,'predict':s.index[0],'pourc':s.values[0],'predict2':s.index[1],'pourc2':s.values[1],'predict3':s.index[2],'pourc3':s.values[2]}])
            df_pred = pd.concat([df_pred, df_temp], ignore_index=True)

# %%
df_pred
# Out:
#     Categorie  predict     pourc  predict2    pourc2  predict3    pourc3
# 0          10       10  0.424572      2705  0.150855      2403  0.127527
# 1          40       40  0.582505      2462  0.055666      2705  0.047714
# 2          50       50  0.739812      2462  0.043887        40  0.040752
# 3          60       60  0.877095      2462  0.055866        50  0.022346
# 4        1140     1140  0.728440      1280  0.088073        40  0.020183
# 5        1160     1160  0.851198      1140  0.027743        10  0.025221
# 6        1180     1180  0.548611      1281  0.083333      1140  0.076389
# 7        1280     1280  0.657685      1281  0.091816      1140  0.045908
# 8        1281     1281  0.578431      1280  0.164216      1180  0.031863
# 9        1300     1300  0.933535      1280  0.021148        10  0.005035
# 10       1301     1301  0.913580      1281  0.030864      1302  0.018519
# 11       1302     1302  0.787938      1280  0.071984      2583  0.021401
# 12       1320     1320  0.733434      2060  0.051205      1280  0.049699
# 13       1560     1560  0.775428      2060  0.085599      2582  0.038268
# 14       1920     1920  0.903846      2060  0.039663      1560  0.028846
# 15       1940     1940  0.716981      1560  0.031447      2280  0.031447
# 16       2060     2060  0.815464      1560  0.048454      1920  0.024742
# 17       2220     2220  0.726316      2585  0.052632      2060  0.042105
# 18       2280     2280  0.771679      2403  0.096597        10  0.055982
# 19       2403     2403  0.682622        10  0.093652      2280  0.081165
# 20       2462     2462  0.757475        50  0.106312        40  0.046512
# 21       2522     2522  0.889219      2403  0.016815      2060  0.015826
# 22       2582     2582  0.686679      1560  0.093809      2060  0.078799
# 23       2583     2583  0.961114      1302  0.010082      2060  0.006721
# 24       2585     2585  0.698718      2582  0.066239      2060  0.044872
# 25       2705     2705  0.698384        10  0.122083      2403  0.050269
# 26       2905     2905  0.924658      2705  0.027397      1281  0.020548

# %%
df_cross
# Out:
# predict          10        40        50        60        1140      1160  \
# prdtypecode
# 10           0.424572  0.037325  0.004666  0.000000  0.010886  0.013997
# 40           0.043738  0.582505  0.043738  0.001988  0.023857  0.025845
# 50           0.003135  0.040752  0.739812  0.040752  0.015674  0.003135
# 60           0.000000  0.016760  0.022346  0.877095  0.016760  0.000000
# 1140         0.016514  0.020183  0.009174  0.000000  0.728440  0.012844
# 1160         0.025221  0.010088  0.002522  0.002522  0.027743  0.851198
# 1180         0.006944  0.013889  0.000000  0.000000  0.076389  0.020833
# 1280         0.006986  0.013972  0.006986  0.000998  0.045908  0.004990
# 1281         0.022059  0.029412  0.002451  0.004902  0.017157  0.019608
# 1300         0.005035  0.002014  0.004028  0.001007  0.005035  0.001007
# 1301         0.006173  0.000000  0.000000  0.000000  0.006173  0.000000
# 1302         0.005837  0.000000  0.000000  0.000000  0.011673  0.003891
# 1320         0.009036  0.001506  0.004518  0.001506  0.003012  0.001506
# 1560         0.002014  0.001007  0.004028  0.000000  0.000000  0.000000
# 1920         0.001202  0.000000  0.000000  0.000000  0.000000  0.000000
# 1940         0.018868  0.006289  0.000000  0.000000  0.006289  0.000000
# 2060         0.001031  0.001031  0.003093  0.000000  0.004124  0.001031
# 2220         0.005263  0.005263  0.005263  0.000000  0.005263  0.000000
# 2280         0.055982  0.006586  0.000000  0.000000  0.009879  0.006586
# 2403         0.093652  0.007284  0.000000  0.001041  0.014568  0.005203
# 2462         0.000000  0.046512  0.106312  0.016611  0.016611  0.013289
# 2522         0.002967  0.000989  0.005935  0.000989  0.002967  0.001978
# 2582         0.003752  0.000000  0.001876  0.001876  0.000000  0.000000
# 2583         0.001920  0.000480  0.000000  0.000000  0.000000  0.000000
# 2585         0.006410  0.002137  0.006410  0.002137  0.004274  0.002137
# 2705         0.122083  0.014363  0.001795  0.000000  0.005386  0.010772
# 2905         0.000000  0.000000  0.006849  0.006849  0.000000  0.000000
#
# predict          1180      1280      1281      1300      1301      1302  \
# prdtypecode
# 10           0.006221  0.018663  0.013997  0.004666  0.000000  0.003110
# 40           0.027833  0.013917  0.043738  0.005964  0.003976  0.007952
# 50           0.003135  0.018809  0.006270  0.009404  0.000000  0.018809
# 60           0.000000  0.000000  0.005587  0.000000  0.000000  0.000000
# 1140         0.014679  0.088073  0.011009  0.009174  0.000000  0.007339
# 1160         0.005044  0.005044  0.008827  0.003783  0.001261  0.000000
# 1180         0.548611  0.034722  0.083333  0.027778  0.000000  0.027778
# 1280         0.017964  0.657685  0.091816  0.026946  0.001996  0.025948
# 1281         0.031863  0.164216  0.578431  0.000000  0.002451  0.029412
# 1300         0.002014  0.021148  0.001007  0.933535  0.000000  0.001007
# 1301         0.000000  0.006173  0.030864  0.000000  0.913580  0.018519
# 1302         0.001946  0.071984  0.011673  0.005837  0.003891  0.787938
# 1320         0.003012  0.049699  0.013554  0.004518  0.001506  0.016566
# 1560         0.000000  0.009063  0.001007  0.001007  0.000000  0.004028
# 1920         0.000000  0.002404  0.000000  0.000000  0.000000  0.002404
# 1940         0.000000  0.012579  0.000000  0.006289  0.006289  0.000000
# 2060         0.000000  0.012371  0.004124  0.001031  0.000000  0.005155
# 2220         0.000000  0.021053  0.000000  0.000000  0.005263  0.005263
# 2280         0.002195  0.003293  0.004391  0.005488  0.001098  0.000000
# 2403         0.002081  0.006243  0.011446  0.001041  0.000000  0.006243
# 2462         0.003322  0.006645  0.009967  0.000000  0.003322  0.009967
# 2522         0.000000  0.011869  0.004946  0.000989  0.000000  0.004946
# 2582         0.001876  0.007505  0.000000  0.001876  0.000000  0.011257
# 2583         0.000000  0.000960  0.000480  0.000480  0.000000  0.010082
# 2585         0.000000  0.010684  0.004274  0.008547  0.000000  0.017094
# 2705         0.005386  0.008977  0.012567  0.000000  0.000000  0.007181
# 2905         0.006849  0.000000  0.020548  0.000000  0.000000  0.000000
#
# predict          1320      1560      1920      1940      2060      2220  \
# prdtypecode
# 10           0.012442  0.004666  0.003110  0.010886  0.009331  0.006221
# 40           0.000000  0.003976  0.000000  0.000000  0.005964  0.001988
# 50           0.000000  0.006270  0.000000  0.000000  0.006270  0.000000
# 60           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1140         0.009174  0.000000  0.001835  0.001835  0.014679  0.000000
# 1160         0.000000  0.000000  0.001261  0.000000  0.005044  0.001261
# 1180         0.020833  0.000000  0.013889  0.006944  0.006944  0.000000
# 1280         0.027944  0.003992  0.002994  0.000000  0.015968  0.003992
# 1281         0.002451  0.002451  0.000000  0.000000  0.014706  0.004902
# 1300         0.002014  0.001007  0.002014  0.000000  0.003021  0.000000
# 1301         0.012346  0.000000  0.000000  0.000000  0.000000  0.000000
# 1302         0.015564  0.013619  0.000000  0.000000  0.013619  0.003891
# 1320         0.733434  0.027108  0.019578  0.001506  0.051205  0.000000
# 1560         0.019134  0.775428  0.026183  0.001007  0.085599  0.001007
# 1920         0.010817  0.028846  0.903846  0.000000  0.039663  0.002404
# 1940         0.018868  0.031447  0.006289  0.716981  0.025157  0.018868
# 2060         0.011340  0.048454  0.024742  0.002062  0.815464  0.002062
# 2220         0.021053  0.015789  0.026316  0.010526  0.042105  0.726316
# 2280         0.002195  0.001098  0.000000  0.002195  0.001098  0.000000
# 2403         0.005203  0.000000  0.001041  0.000000  0.000000  0.001041
# 2462         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2522         0.007913  0.011869  0.000989  0.000989  0.015826  0.000989
# 2582         0.007505  0.093809  0.015009  0.001876  0.078799  0.009381
# 2583         0.001440  0.002400  0.000960  0.000000  0.006721  0.000000
# 2585         0.008547  0.036325  0.008547  0.002137  0.044872  0.019231
# 2705         0.001795  0.008977  0.000000  0.000000  0.005386  0.007181
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          2280      2403      2462      2522      2582      2583  \
# prdtypecode
# 10           0.097978  0.127527  0.009331  0.009331  0.004666  0.004666
# 40           0.013917  0.029821  0.055666  0.007952  0.000000  0.003976
# 50           0.000000  0.003135  0.043887  0.012539  0.003135  0.003135
# 60           0.000000  0.000000  0.055866  0.000000  0.000000  0.000000
# 1140         0.012844  0.003670  0.012844  0.009174  0.001835  0.000000
# 1160         0.011349  0.006305  0.011349  0.003783  0.001261  0.002522
# 1180         0.006944  0.020833  0.013889  0.027778  0.006944  0.000000
# 1280         0.001996  0.005988  0.005988  0.011976  0.001996  0.002994
# 1281         0.009804  0.004902  0.014706  0.009804  0.004902  0.000000
# 1300         0.005035  0.000000  0.000000  0.001007  0.001007  0.003021
# 1301         0.006173  0.000000  0.000000  0.000000  0.000000  0.000000
# 1302         0.000000  0.000000  0.000000  0.001946  0.019455  0.021401
# 1320         0.006024  0.001506  0.000000  0.012048  0.006024  0.012048
# 1560         0.000000  0.001007  0.000000  0.011078  0.038268  0.001007
# 1920         0.000000  0.000000  0.000000  0.002404  0.003606  0.002404
# 1940         0.031447  0.006289  0.000000  0.031447  0.012579  0.006289
# 2060         0.003093  0.004124  0.001031  0.006186  0.022680  0.008247
# 2220         0.000000  0.005263  0.000000  0.010526  0.005263  0.010526
# 2280         0.771679  0.096597  0.001098  0.000000  0.000000  0.000000
# 2403         0.081165  0.682622  0.009365  0.014568  0.002081  0.001041
# 2462         0.003322  0.000000  0.757475  0.003322  0.000000  0.000000
# 2522         0.001978  0.016815  0.001978  0.889219  0.002967  0.001978
# 2582         0.000000  0.001876  0.000000  0.003752  0.686679  0.022514
# 2583         0.000000  0.000000  0.000000  0.000000  0.004801  0.961114
# 2585         0.004274  0.000000  0.000000  0.014957  0.066239  0.029915
# 2705         0.021544  0.050269  0.003591  0.000000  0.001795  0.001795
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.006849
#
# predict          2585      2705      2905
# prdtypecode
# 10           0.009331  0.150855  0.001555
# 40           0.001988  0.047714  0.001988
# 50           0.015674  0.003135  0.003135
# 60           0.000000  0.000000  0.005587
# 1140         0.003670  0.011009  0.000000
# 1160         0.001261  0.011349  0.000000
# 1180         0.000000  0.034722  0.000000
# 1280         0.006986  0.003992  0.000998
# 1281         0.000000  0.029412  0.000000
# 1300         0.004028  0.000000  0.001007
# 1301         0.000000  0.000000  0.000000
# 1302         0.000000  0.003891  0.001946
# 1320         0.010542  0.007530  0.001506
# 1560         0.017120  0.001007  0.000000
# 1920         0.000000  0.000000  0.000000
# 1940         0.012579  0.025157  0.000000
# 2060         0.013402  0.004124  0.000000
# 2220         0.052632  0.015789  0.005263
# 2280         0.003293  0.025247  0.000000
# 2403         0.005203  0.047867  0.000000
# 2462         0.000000  0.003322  0.000000
# 2522         0.005935  0.001978  0.000000
# 2582         0.043152  0.005629  0.000000
# 2583         0.006241  0.001920  0.000000
# 2585         0.698718  0.002137  0.000000
# 2705         0.005386  0.698384  0.005386
# 2905         0.000000  0.027397  0.924658

# %%
for c in Lcat:
    print(c,'   ------   ', catdict[c] )
    s=df_cross.loc[c].sort_values(ascending=False)[:5]
    for index, value in s.items():
        print(f"  : {index},  : {np.round(value*100,2)} % , {catdict[index]}")
# Out:
# 10    ------    livres
#   : 10,  : 42.46 % , livres
#   : 2705,  : 15.09 % , bds et livres
#   : 2403,  : 12.75 % , livres et bds
#   : 2280,  : 9.8 % , magazines
#   : 40,  : 3.73 % , jeux video pour pc et consoles
# 40    ------    jeux video pour pc et consoles
#   : 40,  : 58.25 % , jeux video pour pc et consoles
#   : 2462,  : 5.57 % , consoles de jeux video et jeux videos
#   : 2705,  : 4.77 % , bds et livres
#   : 1281,  : 4.37 % , jeux de societe/cartes
#   : 50,  : 4.37 % ,  accesoires jeux video
# 50    ------     accesoires jeux video
#   : 50,  : 73.98 % ,  accesoires jeux video
#   : 2462,  : 4.39 % , consoles de jeux video et jeux videos
#   : 40,  : 4.08 % , jeux video pour pc et consoles
#   : 60,  : 4.08 % , consoles de jeux video
#   : 1280,  : 1.88 % , jouets, peluches, poupees
# 60    ------    consoles de jeux video
#   : 60,  : 87.71 % , consoles de jeux video
#   : 2462,  : 5.59 % , consoles de jeux video et jeux videos
#   : 50,  : 2.23 % ,  accesoires jeux video
#   : 1140,  : 1.68 % , produits derives “geeks” et figurines
#   : 40,  : 1.68 % , jeux video pour pc et consoles
# 1140    ------    produits derives “geeks” et figurines
#   : 1140,  : 72.84 % , produits derives “geeks” et figurines
#   : 1280,  : 8.81 % , jouets, peluches, poupees
#   : 40,  : 2.02 % , jeux video pour pc et consoles
#   : 10,  : 1.65 % , livres
#   : 1180,  : 1.47 % , figurines collectionables pour jeux de societe
# 1160    ------    cartes collectionables
#   : 1160,  : 85.12 % , cartes collectionables
#   : 1140,  : 2.77 % , produits derives “geeks” et figurines
#   : 10,  : 2.52 % , livres
#   : 2462,  : 1.13 % , consoles de jeux video et jeux videos
#   : 2705,  : 1.13 % , bds et livres
# 1180    ------    figurines collectionables pour jeux de societe
#   : 1180,  : 54.86 % , figurines collectionables pour jeux de societe
#   : 1281,  : 8.33 % , jeux de societe/cartes
#   : 1140,  : 7.64 % , produits derives “geeks” et figurines
#   : 1280,  : 3.47 % , jouets, peluches, poupees
#   : 2705,  : 3.47 % , bds et livres
# 1280    ------    jouets, peluches, poupees
#   : 1280,  : 65.77 % , jouets, peluches, poupees
#   : 1281,  : 9.18 % , jeux de societe/cartes
#   : 1140,  : 4.59 % , produits derives “geeks” et figurines
#   : 1320,  : 2.79 % , sacs pour femmes et accesore petite enfance
#   : 1300,  : 2.69 % , Petites voitures (jouets) et maquettes
# 1281    ------    jeux de societe/cartes
#   : 1281,  : 57.84 % , jeux de societe/cartes
#   : 1280,  : 16.42 % , jouets, peluches, poupees
#   : 1180,  : 3.19 % , figurines collectionables pour jeux de societe
#   : 40,  : 2.94 % , jeux video pour pc et consoles
#   : 1302,  : 2.94 % , jeux d'exterieur
# 1300    ------    Petites voitures (jouets) et maquettes
#   : 1300,  : 93.35 % , Petites voitures (jouets) et maquettes
#   : 1280,  : 2.11 % , jouets, peluches, poupees
#   : 10,  : 0.5 % , livres
#   : 1140,  : 0.5 % , produits derives “geeks” et figurines
#   : 2280,  : 0.5 % , magazines
# 1301    ------    accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
#   : 1301,  : 91.36 % , accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
#   : 1281,  : 3.09 % , jeux de societe/cartes
#   : 1302,  : 1.85 % , jeux d'exterieur
#   : 1320,  : 1.23 % , sacs pour femmes et accesore petite enfance
#   : 1280,  : 0.62 % , jouets, peluches, poupees
# 1302    ------    jeux d'exterieur
#   : 1302,  : 78.79 % , jeux d'exterieur
#   : 1280,  : 7.2 % , jouets, peluches, poupees
#   : 2583,  : 2.14 % , accesoires de piscine
#   : 2582,  : 1.95 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1320,  : 1.56 % , sacs pour femmes et accesore petite enfance
# 1320    ------    sacs pour femmes et accesore petite enfance
#   : 1320,  : 73.34 % , sacs pour femmes et accesore petite enfance
#   : 2060,  : 5.12 % , lampes et accesoires decoration pour maison
#   : 1280,  : 4.97 % , jouets, peluches, poupees
#   : 1560,  : 2.71 % , Mobilier et produits decoration/rangement pour la maison
#   : 1920,  : 1.96 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
# 1560    ------    Mobilier et produits decoration/rangement pour la maison
#   : 1560,  : 77.54 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 8.56 % , lampes et accesoires decoration pour maison
#   : 2582,  : 3.83 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1920,  : 2.62 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 1320,  : 1.91 % , sacs pour femmes et accesore petite enfance
# 1920    ------    linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 1920,  : 90.38 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 2060,  : 3.97 % , lampes et accesoires decoration pour maison
#   : 1560,  : 2.88 % , Mobilier et produits decoration/rangement pour la maison
#   : 1320,  : 1.08 % , sacs pour femmes et accesore petite enfance
#   : 2582,  : 0.36 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# 1940    ------    nouriture (cafes,infusions,conserves, epices,etc)
#   : 1940,  : 71.7 % , nouriture (cafes,infusions,conserves, epices,etc)
#   : 1560,  : 3.14 % , Mobilier et produits decoration/rangement pour la maison
#   : 2280,  : 3.14 % , magazines
#   : 2522,  : 3.14 % , produits de papeterie et rangement bureau
#   : 2705,  : 2.52 % , bds et livres
# 2060    ------    lampes et accesoires decoration pour maison
#   : 2060,  : 81.55 % , lampes et accesoires decoration pour maison
#   : 1560,  : 4.85 % , Mobilier et produits decoration/rangement pour la maison
#   : 1920,  : 2.47 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 2582,  : 2.27 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2585,  : 1.34 % , outillage et accesoires pour jardinage
# 2220    ------    accesoires mascots/pets
#   : 2220,  : 72.63 % , accesoires mascots/pets
#   : 2585,  : 5.26 % , outillage et accesoires pour jardinage
#   : 2060,  : 4.21 % , lampes et accesoires decoration pour maison
#   : 1920,  : 2.63 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 1280,  : 2.11 % , jouets, peluches, poupees
# 2280    ------    magazines
#   : 2280,  : 77.17 % , magazines
#   : 2403,  : 9.66 % , livres et bds
#   : 10,  : 5.6 % , livres
#   : 2705,  : 2.52 % , bds et livres
#   : 1140,  : 0.99 % , produits derives “geeks” et figurines
# 2403    ------    livres et bds
#   : 2403,  : 68.26 % , livres et bds
#   : 10,  : 9.37 % , livres
#   : 2280,  : 8.12 % , magazines
#   : 2705,  : 4.79 % , bds et livres
#   : 2522,  : 1.46 % , produits de papeterie et rangement bureau
# 2462    ------    consoles de jeux video et jeux videos
#   : 2462,  : 75.75 % , consoles de jeux video et jeux videos
#   : 50,  : 10.63 % ,  accesoires jeux video
#   : 40,  : 4.65 % , jeux video pour pc et consoles
#   : 1140,  : 1.66 % , produits derives “geeks” et figurines
#   : 60,  : 1.66 % , consoles de jeux video
# 2522    ------    produits de papeterie et rangement bureau
#   : 2522,  : 88.92 % , produits de papeterie et rangement bureau
#   : 2403,  : 1.68 % , livres et bds
#   : 2060,  : 1.58 % , lampes et accesoires decoration pour maison
#   : 1560,  : 1.19 % , Mobilier et produits decoration/rangement pour la maison
#   : 1280,  : 1.19 % , jouets, peluches, poupees
# 2582    ------    mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2582,  : 68.67 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1560,  : 9.38 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 7.88 % , lampes et accesoires decoration pour maison
#   : 2585,  : 4.32 % , outillage et accesoires pour jardinage
#   : 2583,  : 2.25 % , accesoires de piscine
# 2583    ------    accesoires de piscine
#   : 2583,  : 96.11 % , accesoires de piscine
#   : 1302,  : 1.01 % , jeux d'exterieur
#   : 2060,  : 0.67 % , lampes et accesoires decoration pour maison
#   : 2585,  : 0.62 % , outillage et accesoires pour jardinage
#   : 2582,  : 0.48 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# 2585    ------    outillage et accesoires pour jardinage
#   : 2585,  : 69.87 % , outillage et accesoires pour jardinage
#   : 2582,  : 6.62 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2060,  : 4.49 % , lampes et accesoires decoration pour maison
#   : 1560,  : 3.63 % , Mobilier et produits decoration/rangement pour la maison
#   : 2583,  : 2.99 % , accesoires de piscine
# 2705    ------    bds et livres
#   : 2705,  : 69.84 % , bds et livres
#   : 10,  : 12.21 % , livres
#   : 2403,  : 5.03 % , livres et bds
#   : 2280,  : 2.15 % , magazines
#   : 40,  : 1.44 % , jeux video pour pc et consoles
# 2905    ------    Jeu En téléchargement
#   : 2905,  : 92.47 % , Jeu En téléchargement
#   : 2705,  : 2.74 % , bds et livres
#   : 1281,  : 2.05 % , jeux de societe/cartes
#   : 1180,  : 0.68 % , figurines collectionables pour jeux de societe
#   : 2583,  : 0.68 % , accesoires de piscine

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test_original, test_pred_original)
print(cm[:10,:10])
print('*************************************************')
print(cm[10:20,10:20])
print('*************************************************')
print(cm[20:,20:])
# Out:
# [[273  24   3   0   7   9   4  12   9   3]
#  [ 22 293  22   1  12  13  14   7  22   3]
#  [  1  13 236  13   5   1   1   6   2   3]
#  [  0   3   4 157   3   0   0   0   1   0]
#  [  9  11   5   0 397   7   8  48   6   5]
#  [ 20   8   2   2  22 675   4   4   7   3]
#  [  1   2   0   0  11   3  79   5  12   4]
#  [  7  14   7   1  46   5  18 659  92  27]
#  [  9  12   1   2   7   8  13  67 236   0]
#  [  5   2   4   1   5   1   2  21   1 927]]
# *************************************************
# [[148   3   2   0   0   0   0   0   1   0]
#  [  2 405   8   7   0   0   7   2   0   0]
#  [  1  11 487  18  13   1  34   0   4   1]
#  [  0   4  19 770  26   1  85   1   0   1]
#  [  0   2   9  24 752   0  33   2   0   0]
#  [  1   0   3   5   1 114   4   3   5   1]
#  [  0   5  11  47  24   2 791   2   3   4]
#  [  1   1   4   3   5   2   8 138   0   1]
#  [  1   0   2   1   0   2   1   0 703  88]
#  [  0   6   5   0   1   0   0   1  78 656]]
# *************************************************
# [[ 228    1    0    0    0    1    0]
#  [   2  899    3    2    6    2    0]
#  [   0    2  366   12   23    3    0]
#  [   0    0   10 2002   13    4    0]
#  [   0    7   31   14  327    1    0]
#  [   2    0    1    1    3  389    3]
#  [   0    0    0    1    0    4  135]]

# %%
fig, ax = plt.subplots(figsize=(10,10))
cm_normalized = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis])
#cm_normalized=cm.div(cm.sum(axis=1), axis=0)
cax = ax.matshow(cm_normalized, cmap='Reds')
plt.xticks(range(27),catdict,rotation=90)
plt.yticks(range(27),catdict,rotation=0)
plt.show()

# %% [markdown]
# ## Etude des catégories 10 ; 2280 ; 2403 ; 2705

# %%
df_livres=df_test[df_test['prdtypecode'].isin([10,2280,2403,2705])]
df_livres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3072 entries, 58440 to 46826
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tokenized    3072 non-null   object
#  1   prdtypecode  3072 non-null   int64
#  2   predict      3072 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 96.0+ KB

# %%
df_livres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3072 entries, 58440 to 46826
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tokenized    3072 non-null   object
#  1   prdtypecode  3072 non-null   int64
#  2   predict      3072 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 96.0+ KB

# %%
for c in [10,2280,2403,2705]:
    print(c,'   ------   ', catdict[c] )
    print(df_livres[df_livres['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 10    ------    livres
# predict
# 10      0.424572
# 2705    0.150855
# 2403    0.127527
# 2280    0.097978
# 40      0.037325
# Name: proportion, dtype: float64
# 2280    ------    magazines
# predict
# 2280    0.771679
# 2403    0.096597
# 10      0.055982
# 2705    0.025247
# 1140    0.009879
# Name: proportion, dtype: float64
# 2403    ------    livres et bds
# predict
# 2403    0.682622
# 10      0.093652
# 2280    0.081165
# 2705    0.047867
# 1140    0.014568
# Name: proportion, dtype: float64
# 2705    ------    bds et livres
# predict
# 2705    0.698384
# 10      0.122083
# 2403    0.050269
# 2280    0.021544
# 40      0.014363
# Name: proportion, dtype: float64

# %%
print(df_livres.info())
df_livres.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3072 entries, 58440 to 46826
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tokenized    3072 non-null   object
#  1   prdtypecode  3072 non-null   int64
#  2   predict      3072 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 96.0+ KB
# None
#                                                                                                  tokenized  \
# 58440                                                          [miroir, sprint, n°, campionnissimo, valet]
# 1068   [dictionnaire, etymologique, roman, derom, second, volume, dictionnaire, tymologique, roman, rom...
# 48464                                                                       [compte, rebours, douze, mois]
# 22835                                                                                           [lot, sas]
# 37938  [lot, premiers, tomes, etoiles, hommes, enseignement, christ, maitreya, richard, vitrac, marie, ...
#
#        prdtypecode  predict
# 58440         2280     2280
# 1068          2705     2403
# 48464         2403     1320
# 22835         2403     2403
# 37938         2403     2403

# %%
import pandas as pd
from collections import Counter

# Étape 1 : Identifier les 20 mots les plus fréquents
all_words = sum(df_livres['tokenized'].tolist(), [])
global_word_counts = Counter(all_words)
top_20_words = global_word_counts.most_common(20)

# Étape 2 : Calculer le nombre d'occurrences de chaque mot pour chaque classe et globalement
# Initialiser les données pour le DataFrame
data = {"Word": [word for word, count in top_20_words], "Total": [count for word, count in top_20_words]}
class_ids = df_livres['prdtypecode'].unique()

# Calculer les occurrences par classe pour chaque mot
for class_id in class_ids:
    data[class_id] = []
    for word, _ in top_20_words:
        word_count = sum(row.count(word) for row in df_livres[df_livres['prdtypecode'] == class_id]['tokenized'])
        data[class_id].append(word_count)

# Étape 3 : Créer le DataFrame
df_word_counts = pd.DataFrame(data)
df_word_counts.set_index("Word", inplace=True)

# Afficher le DataFrame
print(df_word_counts)
df_total_livres=df_word_counts
# Out:
#             Total  2280  2705  2403  10
# Word
# n°            962   763     4   151  44
# lot           426     0     0   426   0
# rsquo         369     0   369     0   0
# vie           231    33   151    29  18
# livres        221     5    13   189  14
# monde         179    54   106    14   5
# tome          170     6    58    66  40
# france        160    73    35    33  19
# livre         157     3    83    34  37
# cette         149     3   142     2   2
# histoire      148    24    77    28  19
# temps         108     9    74    14  11
# paris         102    55    26    15   6
# collection    100    10    16    58  16
# jean           97    39    21    25  12
# homme          97     6    78     6   7
# journal        96    66     7    16   7
# edition        96     4     9    40  43
# bien           95     7    85     2   1
# entre          93     6    74     7   6

# %%
fig, ax = plt.subplots(figsize=(2,20))
cax = ax.matshow(df_total_livres.iloc[0:20], cmap = 'coolwarm')
plt.xticks(range(5),(df_total_livres.columns.tolist()),rotation=45)
plt.yticks(range(20),df_total_livres.iloc[0:20].index,rotation=0)
plt.show()

# %% [markdown]
# ## Etude des catégories 1280,1281

# %%
df_jouets=df_test[df_test['prdtypecode'].isin([1280,1281])]

# %%
for c in [1280,1281]:
    print(c,'   ------   ', catdict[c] )
    print(df_jouets[df_jouets['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 1280    ------    jouets, peluches, puppets
# predict
# 1280    0.699601
# 1281    0.065868
# 1140    0.039920
# 1320    0.026946
# 1300    0.021956
# Name: proportion, dtype: float64
# 1281    ------    jeux de societe/cartes
# predict
# 1281    0.512255
# 1280    0.235294
# 1180    0.034314
# 10      0.031863
# 1160    0.029412
# Name: proportion, dtype: float64

# %%
import pandas as pd
from collections import Counter

# Étape 1 : Identifier les 20 mots les plus fréquents
all_words = sum(df_jouets['tokenized'].tolist(), [])
global_word_counts = Counter(all_words)
top_20_words = global_word_counts.most_common(20)

# Étape 2 : Calculer le nombre d'occurrences de chaque mot pour chaque classe et globalement
# Initialiser les données pour le DataFrame
data = {"Word": [word for word, count in top_20_words], "Total": [count for word, count in top_20_words]}
class_ids = df_jouets['prdtypecode'].unique()

# Calculer les occurrences par classe pour chaque mot
for class_id in class_ids:
    data[class_id] = []
    for word, _ in top_20_words:
        word_count = sum(row.count(word) for row in df_jouets[df_jouets['prdtypecode'] == class_id]['tokenized'])
        data[class_id].append(word_count)

# Étape 3 : Créer le DataFrame
df_word_counts = pd.DataFrame(data)
df_word_counts.set_index("Word", inplace=True)

# Afficher le DataFrame
df_word_counts
df_total_livres=df_word_counts
df_word_counts
# Out:
#           Total  1280  1281
# Word
# enfants    1350   940   410
# jouet       594   445   149
# jouets      593   435   158
# bebe        546   416   130
# taille      529   423   106
# haute       432   337    95
# jeu         415   184   231
# couleur     372   289    83
# toy         372   290    82
# qualite     371   276    95
# etre        367   289    78
# cadeau      345   244   101
# poupee      336   247    89
# non         305   206    99
# voiture     299   263    36
# bois        286   194    92
# materiel    285   227    58
# jouer       275   188    87
# produit     273   213    60
# batterie    264   241    23

# %%
fig, ax = plt.subplots(figsize=(2,20))
cax = ax.matshow(df_total_livres.iloc[0:20], cmap = 'coolwarm')
plt.xticks(range(3),(df_total_livres.columns.tolist()),rotation=45)
plt.yticks(range(20),df_total_livres.iloc[0:20].index,rotation=0)
plt.show()
