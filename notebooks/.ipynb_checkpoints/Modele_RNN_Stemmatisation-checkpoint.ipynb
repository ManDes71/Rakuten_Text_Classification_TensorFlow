# %% [markdown]
# <a href="https://colab.research.google.com/github/ManDes71/Rakuten_Text_Classification_TensorFlow/blob/main/notebooks/Modele_RNN_Stemmatisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Le NLTK, ou Natural Language Toolkit, est une suite de bibliothèques logicielles et de programmes. Elle est conçue pour le traitement naturel symbolique et statistique du langage anglais en langage Python. C’est l’une des bibliothèques de traitement naturel du langage les plus puissantes.**

# %% [markdown]
# **La méthode du *Stemming* permet de convertir un ensemble de mots dans une phrase en une séquence, Les mots ayant le même sens, mais varient en fonction du contexte sont ainsi normalisée. Le but est de trouver la racine à partir des différentes variations du mot. Le NLTK regroupe plusieurs « stemmers » comme le Porter Stemmer, le Snowball Stemmer et le Lancaster Stemmer.**

# %% [markdown]
# ***Google Colab -> Cette cellule est à executer (1 fois) pour le cloner le dépot en local***
# il est possible que google colab vous demande re demarrer la session

# %%
# !git clone https://github.com/ManDes71/Rakuten_Text_Classification_TensorFlow.git
# Out:
# Cloning into 'Rakuten_Text_Classification_TensorFlow'...
# remote: Enumerating objects: 582, done.
# remote: Counting objects: 100% (218/218), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 582 (delta 185), reused 132 (delta 126), pack-reused 364
# Receiving objects: 100% (582/582), 41.54 MiB | 14.99 MiB/s, done.
# Resolving deltas: 100% (380/380), done.

# %% [markdown]
# **Google Colab -> Cette cellule est à executer (2 fois) pour installer les bibliothèques nécessaires**
# You must restart the runtime in order to use newly installed versions.

# %%
import sys
sys.path.append('/content/Rakuten_Text_Classification_TensorFlow')
# !pip install -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt
# Out:
# Requirement already satisfied: joblib==1.2.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: keras==2.10.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 2)) (2.10.0)
# Requirement already satisfied: langdetect==1.0.7 in /usr/local/lib/python3.10/dist-packages (from -r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 3)) (1.0.7)
# ...
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0->-r /content/Rakuten_Text_Classification_TensorFlow/requirements.txt (line 11)) (3.2.2)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from keras.optimizers import SGD,Adam
from tensorflow.keras.utils import to_categorical

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, GlobalAveragePooling1D, RNN, GRUCell
from tensorflow.keras.layers import  Dropout ,Conv1D,Flatten,Bidirectional,LSTM,BatchNormalization

from nltk.tokenize import PunktSentenceTokenizer
from nltk.tokenize.regexp import RegexpTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.metrics import f1_score, make_scorer,accuracy_score,classification_report
import nltk
import re

from sklearn import svm
import unicodedata
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import swifter

# Ajuster la largeur maximale des colonnes à 100 pour éviter la troncature
pd.set_option('display.max_colwidth', 100)

# set the max columns to none
pd.set_option('display.max_columns', None)

# %%
MAXLEN = 600
NUM_WORDS = 70000
EMBEDDING_DIM = 200

# %%
import configparser
import sys
#sys.path.append('../src')
sys.path.append('/content/Rakuten_Text_Classification_TensorFlow/src')
import Bibli_DataScience_3_3 as ds
config = configparser.ConfigParser()
config.read('Rakuten_config_colab.ini')
# Out:
# section :  ['DOSSIER', 'FICHIER']
# []

# %%
import pandas as pd

# lecture des données sources d'entrainement
df_feats=pd.read_csv(ds.get_RACINE_DOSSIER() + 'X_train_update.csv')

# lecture des données cibles d'entrainement
df_target=pd.read_csv(ds.get_RACINE_DOSSIER() + 'Y_train_CVw08PX.csv')


# création d'un dataframe globale -  jointure
df=df_feats.merge(df_target,on='Unnamed: 0',how='inner')
df.rename(columns={'Unnamed: 0': 'Id'}, inplace=True)

# récupération du fichier df_langue.csv
df_langue=pd.read_csv(ds.get_RACINE_DOSSIER() + 'df_langue.csv')
df=df.merge(df_langue.drop(['Unnamed: 0','prdtypecode'], axis=1),on='Id',how='inner')

Lcat=df_target.sort_values(by='prdtypecode')['prdtypecode'].unique()


nomenclature=pd.read_csv(ds.get_RACINE_DOSSIER() + 'NOMENCLATURE.csv',header=0,encoding='utf-8',sep=';',index_col=0)
catdict=nomenclature.to_dict()['definition']

#
stopwordFR = pd.read_csv(ds.get_RACINE_DOSSIER() + 'stopwords_FR_02.csv')
stop_words = stopwordFR['MOT'].tolist()
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df_feats
# Out:
#        Unnamed: 0  \
# 0               0
# 1               1
# 2               2
# 3               3
# 4               4
# ...           ...
# 84911       84911
# 84912       84912
# 84913       84913
# 84914       84914
# 84915       84915
#
#                                                                                                designation  \
# 0                 Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
# 1      Journal Des Arts (Le) N° 133 Du 28/09/2001 - L'art Et Son Marche Salon D'art Asiatique A Paris -...
# 2                             Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style
# 3                                          Peluche Donald - Europe - Disneyland 2000 (Marionnette À Doigt)
# 4                                                                                     La Guerre Des Tuques
# ...                                                                                                    ...
# 84911                                                                          The Sims [ Import Anglais ]
# 84912                                                 Kit piscine acier NEVADA déco pierre Ø 3.50m x 0.90m
# 84913  Journal Officiel De La Republique Francaise N° 46 Du 15/02/1871 - Changement D'adresses - Partie...
# 84914                                      Table Basse Bois De Récupération Massif Base Blanche 60x60x33cm
# 84915                                               Gomme De Collection 2 Gommes Pinguin Glace Vert Orange
#
#                                                                                                description  \
# 0                                                                                                      NaN
# 1                                                                                                      NaN
# 2      PILOT STYLE Touch Pen de marque Speedlink est 1 stylet ergonomique pour GamePad Nintendo Wii U.<...
# 3                                                                                                      NaN
# 4      Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de boules de neige et s'a...
# ...                                                                                                    ...
# 84911                                                                                                  NaN
# 84912  <b>Description complète :</b><br />Kit piscine hors-sol Toi PIEDRA GRIS ronde Ø 3.50m hauteur 0....
# 84913                                                                                                  NaN
# 84914  <p>Cette table basse a un design unique et constituera un ajout intemporel à votre maison. Son d...
# 84915                                                                                                  NaN
#
#         productid     imageid
# 0      3804725264  1263597046
# 1       436067568  1008141237
# 2       201115110   938777978
# 3        50418756   457047496
# 4       278535884  1077757786
# ...           ...         ...
# 84911   206719094   941495734
# 84912  3065095706  1188462883
# 84913   440707564  1009325617
# 84914  3942400296  1267353403
# 84915    57203227   684671297
#
# [84916 rows x 5 columns]

# %%
df_target
# Out:
#        Unnamed: 0  prdtypecode
# 0               0           10
# 1               1         2280
# 2               2           50
# 3               3         1280
# 4               4         2705
# ...           ...          ...
# 84911       84911           40
# 84912       84912         2583
# 84913       84913         2280
# 84914       84914         1560
# 84915       84915         2522
#
# [84916 rows x 2 columns]

# %%
import pandas as pd

def combine_description_and_designation(row):
    partie_design = row['designation'] if isinstance(row['designation'], str) else ''
    partie_descrip = row['description'] if isinstance(row['description'], str) else ''
    return partie_design + ' ' + partie_descrip if len(partie_descrip) > 0 else partie_design

# Appliquer la fonction à chaque ligne
df_feats['phrases'] = df_feats.swifter.apply(combine_description_and_designation, axis=1)
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]

# %%
print(df_feats.loc[4,['phrases']])
# Out:
# phrases    La Guerre Des Tuques Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de b...
# Name: 4, dtype: object

# %% [markdown]
# # ETAPE 1 :
# ## Passage en minuscule
# Dans un premier temps, nous transformons les majuscules en minuscules car les étapes suivantes sont sensibles à la casse
# ## ETAPE 2: Tokenisation
#  Il s’agit de décomposer une phrase, et donc un document, en tokens. Un token est un élément correspondant à un mot ou une ponctuation, cependant de nombreux cas ne sont pas triviaux à traiter :
# Les mots avec un trait d’union, exemple : peut être et peut-être qui ont des significations très différentes ;
# Les dates et heures qui peuvent être séparées par des points, des slashs, des deux points ;
# Les apostrophes ;
# Les caractères spéciaux : émoticônes, formules mathématiques.

# %%
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')

def preprocess_sentence(w):
    w = str(w)
    # Remplacer les entités HTML par des caractères spécifiques ou les supprimer
    replacements = {
        '&eacute;': 'e',
        '&amp;': '',    # Esperluette
        '&lt;': '',     # Inférieur à
        '&gt;': '',     # Supérieur à
        '&quot;': '',   # Guillemet double
        '&apos;': '',   # Apostrophe
        '&nbsp;': '',   # Espace insécable
        '&copy;': '',   # Droit d'auteur
        '&reg;': '',    # Marque déposée
        '&euro;': '',   # Symbole de l'euro
        '&rsquo;': '',
        '&agrave;': 'a',
        '&ccedil;': 'c',
        '&egrave;': 'e',
        '&iacute;': 'i',
        '&ntilde;': 'n',
        '&ouml;': 'o',
    }
    for entity, replacement in replacements.items():
        w = w.replace(entity, replacement)
    w = unicode_to_ascii(w.lower().strip())
    w = w.replace("n°", "??numero??")
    w = re.sub(r"([?.!,¿])", r" \1 ", w)
    w = re.sub(r'[" "]+', " ", w)
    w = re.sub(r"[^a-zA-Z?.!°]+", " ", w)
    w = re.sub(r'\b\w{0,2}\b', '', w)
    w = w.replace("? ? numero ? ?", "n°")


    # Suppression des stopwords
    mots = word_tokenize(w.strip())
    mots = [mot for mot in mots if mot not in stop_words]
    return ' '.join(mots).strip()

df_feats['WordRNN'] = df_feats['phrases'].swifter.apply(lambda x :preprocess_sentence(x))
df_feats.head()
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#                                                                                            designation  \
# 0             Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L'art Et Son Marche Salon D'art Asiatique A Paris -...
# 2                         Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style
# 3                                      Peluche Donald - Europe - Disneyland 2000 (Marionnette À Doigt)
# 4                                                                                 La Guerre Des Tuques
#
#                                                                                            description  \
# 0                                                                                                  NaN
# 1                                                                                                  NaN
# 2  PILOT STYLE Touch Pen de marque Speedlink est 1 stylet ergonomique pour GamePad Nintendo Wii U.<...
# 3                                                                                                  NaN
# 4  Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de boules de neige et s'a...
#
#     productid     imageid  \
# 0  3804725264  1263597046
# 1   436067568  1008141237
# 2   201115110   938777978
# 3    50418756   457047496
# 4   278535884  1077757786
#
#                                                                                                phrases  \
# 0             Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
# 1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L'art Et Son Marche Salon D'art Asiatique A Paris -...
# 2  Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style PILOT STYLE Touch P...
# 3                                      Peluche Donald - Europe - Disneyland 2000 (Marionnette À Doigt)
# 4  La Guerre Des Tuques Luc a des id&eacute;es de grandeur. Il veut organiser un jeu de guerre de b...
#
#                                                                                                WordRNN
# 0                                olivia personalisiertes notizbuch seiten punktraster din rosen design
# 1  journal arts n° art marche salon art asiatique paris jacques barrere francois perrier reforme ve...
# 2  grand stylet ergonomique bleu gamepad nintendo wii speedlink pilot style pilot style touch pen m...
# 3                                                   peluche donald europe disneyland marionnette doigt
# 4  guerre tuques luc idees grandeur . veut organiser jeu guerre boules neige arranger vainqueur inc...

# %% [markdown]
# ## ETAPE 3: Retrait des stopwords
# Ensuite, nous retirons les mots appartenant aux stopwords. Il s’agit de listes de mots définies au préalable soit par l’utilisateur soit dans des librairies existantes. Ces listes se composent de mots qui n’apportent aucune information, qui sont en général très courants et donc présents dans la plupart des documents, par exemple : je, nous, avoir (le verbe et ses conjugaisons). La suppression de ces stopwords permet de ne pas polluer les représentations des documents afin qu’elle ne contienne que les mots représentatifs et significatifs. Ce “nettoyage” du texte peut aussi s’accompagner de la suppression d’autres éléments comme les nombres, les dates, la ponctuation etc.

# %%
import string
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

nltk.download('punkt')
nltk.download('stopwords')

# Ajustement de la fonction preprocess_text
def preprocess_text(text):
    try:
        lang = detect(text)
    except:
        lang = "fr"  # Définit le français comme langue par défaut
    #text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Utilise le français comme langue de fallback pour la tokenisation
    tokens = word_tokenize(text, language='french' if lang not in ['en', 'es', 'de', 'nl', 'it', 'ca'] else lang)
    # Définit le français comme langue de fallback pour les stop words
    stop_words = set(stopwords.words({
        'en': 'english',
        'es': 'spanish',
        'de': 'german',
        'nl': 'dutch',
        'it': 'italian',
        'ca': 'french',  # Utilise explicitement le français pour le catalan
        'fr': 'french'
    }.get(lang, 'french')))  # Fallback sur le français pour toute autre langue non spécifiée

    tokens = [word for word in tokens if word not in stop_words]
    return tokens

# Supposons df_feats est votre DataFrame et 'concatenated' la colonne à traiter
# Appliquer preprocess_text à chaque valeur de la colonne 'concatenated'
df_feats['tokenized'] = df_feats['WordRNN'].swifter.apply(preprocess_text)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]

# %% [markdown]
# ## ETAPE 4 : Groupement sémantique
# Dès lors, nous disposons pour chaque document d’une liste “nettoyée” de mots porteurs de sens et séparés en tokens. Mais un mot peut être écrit au pluriel, au singulier ou avec différents accords et les verbes peuvent être conjugués à différents temps et personnes.
# Nous devons donc réduire les différences grammaticales des mots en trouvant des formes communes. Pour ce faire, nous disposons de deux méthodes distinctes :
# La stemmatisation, qui ne prend pas en compte le contexte de la phrase
# La lemmatisation, qui prend en compte le contexte
# ### ETAPE 4.1 : La stemmatisation
# La stemmatisation (ou racinisation) réduit les mots à leur radical ou racine.

# %%
X_text_train, X_text_test, y_train, y_test = train_test_split(df_feats.tokenized, df_target.prdtypecode, test_size=0.2, random_state=1234)

# %%
from nltk.stem.snowball import SnowballStemmer
def preprocess_stemmer(tokens):
    # Détection de la langue
    try:
        lang = detect(' '.join(tokens))
    except:
        lang = "fr"  # Langue par défaut
    # Adaptation des ressources linguistiques en fonction de la langue détectée
    if lang == 'en':
        stop_words = set(stopwords.words('english'))
        stemmer = SnowballStemmer("english")
    elif lang == 'es':
        stop_words = set(stopwords.words('spanish'))
        stemmer = SnowballStemmer("spanish")
    elif lang == 'de':
        stop_words = set(stopwords.words('german'))
        stemmer = SnowballStemmer("german")
    elif lang == 'nl':
        stop_words = set(stopwords.words('dutch'))
        stemmer = SnowballStemmer("dutch")
    elif lang == 'it':
        stop_words = set(stopwords.words('italian'))
        stemmer = SnowballStemmer("italian")
    elif lang == 'ca':
        stop_words = set(stopwords.words('french'))
        stemmer = SnowballStemmer("french")
    else:
        stop_words = set(stopwords.words('french'))
        stemmer = SnowballStemmer("french")


    preprocessed_tokens = []
    for token in tokens:
        # Conversion en minuscules et suppression de la ponctuation
        token = token.lower()
        token = token.translate(str.maketrans('', '', string.punctuation))
        # Stemming et suppression des stopwords
        if token not in stop_words and token != '':
            stemmed_token = stemmer.stem(token)
            preprocessed_tokens.append(stemmed_token)

    return preprocessed_tokens

# %% [markdown]
# ### ETAPE 5 : Word Embedding
#  Le word embedding (plongement de mots) désigne un ensemble de méthode d’apprentissage visant à représenter les mots d’un texte par des vecteurs de nombres réels.
#  le word embedding est capable en réduisant la dimension de capturer le contexte, la similarité sémantique et syntaxique (genre, synonymes, …) d’un mot. Par exemple, on pourrait s’attendre à ce que les mots « chien » et « chat » soient représentés par des vecteurs relativement peu distants dans l’espace vectoriel où sont définis ces vecteurs.
#
# Comme pour les images, nous souhaitons que ça soit le modèle qui choisisse les caractéristiques les plus pertinentes représentant le mot. Par exemple, la caractéristique « être vivant » pourrait être intéressante pour différencier « chien » et « ordinateur », et rapprocher « chien » et « chat ».

# %%
# Application de la fonction de prétraitement adaptée
X_text_train_preprocessed = [preprocess_stemmer(tokens) for tokens in X_text_train]
X_text_test_preprocessed = [preprocess_stemmer(tokens) for tokens in X_text_test]

# Puis, continuez avec la tokenisation (dans ce cas, la re-tokenisation) et le padding
tokenizer = Tokenizer()
tokenizer.fit_on_texts([' '.join(tokens) for tokens in X_text_train_preprocessed])


X_train = tokenizer.texts_to_sequences([' '.join(tokens) for tokens in X_text_train_preprocessed])
X_test = tokenizer.texts_to_sequences([' '.join(tokens) for tokens in X_text_test_preprocessed])


X_train = tf.keras.preprocessing.sequence.pad_sequences(X_train, maxlen=MAXLEN, padding='post', truncating='post')
X_test = tf.keras.preprocessing.sequence.pad_sequences(X_test, maxlen=MAXLEN, padding='post', truncating='post')



print("Séquences tokenisées, stemmées et paddées :")
# Out:
# Séquences tokenisées, stemmées et paddées :

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
label_encoder = LabelEncoder()
y_classes_converted = label_encoder.fit_transform(y_train)

y_train_Network = to_categorical(y_classes_converted)
y_classes_converted = label_encoder.transform(y_test)

y_test_Network = to_categorical(y_classes_converted)
print(y_train_Network.shape)
print(y_test_Network.shape)
# Out:
# (67932, 27)
# (16984, 27)

# %%
from tensorflow.keras.layers import  Dropout ,Conv1D,Flatten,Bidirectional,GRU,BatchNormalization

# %%
vocab_size = len(tokenizer.word_index) + 1  # Taille du vocabulaire
embedding_dim = EMBEDDING_DIM  # Dimension de l'espace d'embedding
max_length = MAXLEN  # Déjà calculé lors du prétraitement
num_categories = 27  # Nombre de catégories


model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_length))
model.add(Conv1D(filters=32, kernel_size=8, activation='relu'))
# Ajout d'une couche GRU
model.add(GRU(128, return_sequences=True))
model.add(GlobalAveragePooling1D())
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))  # Augmentation du taux de dropout pour réduire le surajustement
model.add(Dense(num_categories, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 600, 200)          16817800
#
#  conv1d (Conv1D)             (None, 593, 32)           51232
#
#  gru (GRU)                   (None, 593, 128)          62208
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 256)               33024
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 27)                6939
#
# =================================================================
# Total params: 16,972,227
# Trainable params: 16,971,715
# Non-trainable params: 512
# _________________________________________________________________

# %%
from tensorflow.keras import callbacks
lr_plateau = callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                            patience=4,
                            factor=0.5,
                            verbose=1,
                            mode='min')

# %%
model.compile(optimizer=Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entraînement
training_history = model.fit(X_train, y_train_Network, epochs=5, validation_split=0.2,callbacks=[lr_plateau])  # Ajustez selon vos besoins
# Évaluation
loss, accuracy = model.evaluate(X_test, y_test_Network)
print(f'Loss: {loss}, Accuracy: {accuracy}')
# Out:
# Epoch 1/5
# 1699/1699 [==============================] - 2302s 1s/step - loss: 1.3341 - accuracy: 0.6099 - val_loss: 0.7874 - val_accuracy: 0.7760 - lr: 0.0010
# Epoch 2/5
# 1699/1699 [==============================] - 2323s 1s/step - loss: 0.5559 - accuracy: 0.8371 - val_loss: 0.7085 - val_accuracy: 0.7955 - lr: 0.0010
# Epoch 3/5
# 1699/1699 [==============================] - 2347s 1s/step - loss: 0.2978 - accuracy: 0.9136 - val_loss: 0.7645 - val_accuracy: 0.8013 - lr: 0.0010
# Epoch 4/5
# 1699/1699 [==============================] - 2347s 1s/step - loss: 0.1712 - accuracy: 0.9509 - val_loss: 0.8743 - val_accuracy: 0.7978 - lr: 0.0010
# Epoch 5/5
# 1699/1699 [==============================] - 2357s 1s/step - loss: 0.1106 - accuracy: 0.9686 - val_loss: 1.0240 - val_accuracy: 0.7957 - lr: 0.0010
# 531/531 [==============================] - 111s 210ms/step - loss: 1.0357 - accuracy: 0.7961
# Loss: 1.035660743713379, Accuracy: 0.7961022257804871

# %%
predictions = model.predict(X_test)
y_pred = np.argmax(predictions, axis=1)
test_pred_original=label_encoder.inverse_transform(y_pred)
test_pred_original
# Out:
# 531/531 [==============================] - 118s 221ms/step
# array([2522, 1920, 2280, ..., 2583, 1160, 2462])

# %%
train_acc = training_history.history['accuracy']
val_acc = training_history.history['val_accuracy']
tloss = training_history.history['loss']
tvalloss=training_history.history['val_loss']

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(tloss)
plt.plot(tvalloss)
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')



plt.subplot(122)
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('Model acc by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right');

# %% [markdown]
# ### Rapport de classification

# %%
y_test_original=y_test
# On évalue le niveau de précision de notre prédiction.
print("Précision de la prédiction:", accuracy_score(y_test_original, test_pred_original)*100, '%')

print("Evaluation détaillée de la Classification par RDF :\n \n" ,
      (classification_report(y_test_original, test_pred_original)))
# Out:
# Précision de la prédiction: 79.61022138483278 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.47      0.43      0.45       643
#           40       0.67      0.67      0.67       503
#           50       0.71      0.82      0.76       319
#           60       0.91      0.88      0.90       179
#         1140       0.75      0.74      0.74       545
#         1160       0.87      0.85      0.86       793
#         1180       0.77      0.49      0.60       144
#         1280       0.64      0.76      0.69      1002
#         1281       0.57      0.51      0.54       408
#         1300       0.96      0.90      0.93       993
#         1301       0.97      0.90      0.93       162
#         1302       0.71      0.80      0.76       514
#         1320       0.81      0.78      0.80       664
#         1560       0.77      0.85      0.81       993
#         1920       0.90      0.91      0.91       832
#         1940       0.93      0.69      0.79       159
#         2060       0.80      0.78      0.79       970
#         2220       0.82      0.74      0.78       190
#         2280       0.82      0.82      0.82       911
#         2403       0.68      0.75      0.71       961
#         2462       0.72      0.74      0.73       301
#         2522       0.92      0.88      0.90      1011
#         2582       0.78      0.63      0.70       533
#         2583       0.98      0.96      0.97      2083
#         2585       0.70      0.76      0.73       468
#         2705       0.73      0.66      0.70       557
#         2905       0.97      1.00      0.99       146
#
#     accuracy                           0.80     16984
#    macro avg       0.79      0.77      0.78     16984
# weighted avg       0.80      0.80      0.80     16984

# %%
print(X_text_train.info())
print( y_train.info())
print(X_text_test.info())
print( y_test.info())
# Out:
# <class 'pandas.core.series.Series'>
# Index: 67932 entries, 73797 to 58067
# Series name: tokenized
# Non-Null Count  Dtype
# --------------  -----
# 67932 non-null  object
# dtypes: object(1)
# memory usage: 1.0+ MB
# None
# <class 'pandas.core.series.Series'>
# Index: 67932 entries, 73797 to 58067
# Series name: prdtypecode
# Non-Null Count  Dtype
# --------------  -----
# 67932 non-null  int64
# dtypes: int64(1)
# memory usage: 1.0 MB
# None
# <class 'pandas.core.series.Series'>
# Index: 16984 entries, 66047 to 51817
# Series name: tokenized
# Non-Null Count  Dtype
# --------------  -----
# 16984 non-null  object
# dtypes: object(1)
# memory usage: 265.4+ KB
# None
# <class 'pandas.core.series.Series'>
# Index: 16984 entries, 66047 to 51817
# Series name: prdtypecode
# Non-Null Count  Dtype
# --------------  -----
# 16984 non-null  int64
# dtypes: int64(1)
# memory usage: 265.4 KB
# None

# %%
import pandas as pd
df_test = pd.DataFrame({'tokenized': X_text_test, 'prdtypecode': y_test})
df_test['predict']=test_pred_original
df_test.head()
# Out:
#                                                                                                  tokenized  \
# 66047  [stabilo, lot, stylos, feutre, film, ohpen, universal, indelebile, rouge, stabilo, stylo, feutre...
# 29942  [housse, fauteuil, integrale, elastique, protectrice, vert, marque, homescapes, matiere, coton, ...
# 58440                                                          [miroir, sprint, n°, campionnissimo, valet]
# 55079                                                            [brisons, glace, cold, hearted, icecrown]
# 11424  [little, prince, resine, prince, accueil, table, figurine, ornement, magideal, description, vede...
#
#        prdtypecode  predict
# 66047         2522     2522
# 29942         1920     1920
# 58440         2280     2280
# 55079         1160     1281
# 11424         2060     1280

# %% [markdown]
# ### Tableau des 5 classes les plus prédites pour chaque classe réélle

# %%
for c in Lcat:
    print(c,'   ------   ', catdict[c] )
    print(df_test[df_test['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 10    ------    livres
# predict
# 10      0.430793
# 2403    0.185070
# 2705    0.111975
# 2280    0.079316
# 40      0.052877
# Name: proportion, dtype: float64
# 40    ------    jeux video pour pc et consoles
# predict
# 40      0.671968
# 10      0.061630
# 2462    0.039761
# 50      0.035785
# 1281    0.033797
# Name: proportion, dtype: float64
# 50    ------     accesoires jeux video
# predict
# 50      0.818182
# 1280    0.031348
# 2462    0.028213
# 40      0.021944
# 1140    0.021944
# Name: proportion, dtype: float64
# 60    ------    consoles de jeux video
# predict
# 60      0.882682
# 50      0.039106
# 2462    0.033520
# 40      0.022346
# 2705    0.005587
# Name: proportion, dtype: float64
# 1140    ------    produits derives “geeks” et figurines
# predict
# 1140    0.741284
# 1280    0.095413
# 40      0.022018
# 1160    0.020183
# 2403    0.018349
# Name: proportion, dtype: float64
# 1160    ------    cartes collectionables
# predict
# 1160    0.846154
# 10      0.037831
# 40      0.020177
# 1140    0.020177
# 1281    0.017654
# Name: proportion, dtype: float64
# 1180    ------    figurines collectionables pour jeux de societe
# predict
# 1180    0.493056
# 1140    0.090278
# 1281    0.062500
# 1280    0.062500
# 1160    0.041667
# Name: proportion, dtype: float64
# 1280    ------    jouets, peluches, poupees
# predict
# 1280    0.764471
# 1140    0.048902
# 1281    0.037924
# 1302    0.028942
# 1320    0.018962
# Name: proportion, dtype: float64
# 1281    ------    jeux de societe/cartes
# predict
# 1281    0.514706
# 1280    0.276961
# 1302    0.044118
# 40      0.031863
# 1160    0.026961
# Name: proportion, dtype: float64
# 1300    ------    Petites voitures (jouets) et maquettes
# predict
# 1300    0.900302
# 1280    0.059416
# 1140    0.006042
# 2280    0.005035
# 1302    0.004028
# Name: proportion, dtype: float64
# 1301    ------    accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
# predict
# 1301    0.901235
# 1302    0.030864
# 1281    0.024691
# 40      0.012346
# 1320    0.012346
# Name: proportion, dtype: float64
# 1302    ------    jeux d'exterieur
# predict
# 1302    0.803502
# 1280    0.099222
# 1281    0.023346
# 2583    0.011673
# 1320    0.011673
# Name: proportion, dtype: float64
# 1320    ------    sacs pour femmes et accesore petite enfance
# predict
# 1320    0.784639
# 1280    0.051205
# 2060    0.030120
# 1560    0.022590
# 1920    0.019578
# Name: proportion, dtype: float64
# 1560    ------    Mobilier et produits decoration/rangement pour la maison
# predict
# 1560    0.849950
# 2060    0.045317
# 2582    0.025176
# 1920    0.022155
# 2585    0.018127
# Name: proportion, dtype: float64
# 1920    ------    linge de maison (cousins, rideaux, serviettes, nappes, draps)
# predict
# 1920    0.908654
# 1560    0.038462
# 2060    0.024038
# 1320    0.013221
# 2522    0.006010
# Name: proportion, dtype: float64
# 1940    ------    nouriture (cafes,infusions,conserves, epices,etc)
# predict
# 1940    0.691824
# 10      0.069182
# 1280    0.031447
# 1300    0.031447
# 1320    0.025157
# Name: proportion, dtype: float64
# 2060    ------    lampes et accesoires decoration pour maison
# predict
# 2060    0.776289
# 1560    0.061856
# 1920    0.030928
# 2582    0.027835
# 1280    0.018557
# Name: proportion, dtype: float64
# 2220    ------    accesoires mascots/pets
# predict
# 2220    0.736842
# 2585    0.089474
# 1560    0.047368
# 1320    0.036842
# 40      0.015789
# Name: proportion, dtype: float64
# 2280    ------    magazines
# predict
# 2280    0.822173
# 2403    0.092206
# 10      0.040615
# 2705    0.010977
# 1160    0.009879
# Name: proportion, dtype: float64
# 2403    ------    livres et bds
# predict
# 2403    0.745057
# 10      0.086368
# 2280    0.068678
# 2705    0.022893
# 1160    0.015609
# Name: proportion, dtype: float64
# 2462    ------    consoles de jeux video et jeux videos
# predict
# 2462    0.744186
# 50      0.102990
# 40      0.049834
# 60      0.026578
# 2403    0.016611
# Name: proportion, dtype: float64
# 2522    ------    produits de papeterie et rangement bureau
# predict
# 2522    0.880317
# 1280    0.024728
# 2403    0.024728
# 1560    0.013848
# 1281    0.009891
# Name: proportion, dtype: float64
# 2582    ------    mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# predict
# 2582    0.628518
# 1560    0.159475
# 2585    0.069418
# 2060    0.054409
# 1302    0.022514
# Name: proportion, dtype: float64
# 2583    ------    accesoires de piscine
# predict
# 2583    0.960634
# 2585    0.010562
# 1302    0.010082
# 2060    0.004801
# 1560    0.002400
# Name: proportion, dtype: float64
# 2585    ------    outillage et accesoires pour jardinage
# predict
# 2585    0.762821
# 1560    0.038462
# 2582    0.034188
# 1302    0.034188
# 2060    0.032051
# Name: proportion, dtype: float64
# 2705    ------    bds et livres
# predict
# 2705    0.664273
# 10      0.141831
# 2403    0.071813
# 40      0.026930
# 2280    0.021544
# Name: proportion, dtype: float64
# 2905    ------    Jeu En téléchargement
# predict
# 2905    1.0
# Name: proportion, dtype: float64

# %%
top5_df = pd.DataFrame({'prdtypecode':y_test_original ,'predict': test_pred_original})

df_cross=pd.crosstab(top5_df['prdtypecode'], top5_df['predict'],normalize='index')
top5_df.head()
# Out:
#        prdtypecode  predict
# 66047         2522     2522
# 29942         1920     1920
# 58440         2280     2280
# 55079         1160     1281
# 11424         2060     1280

# %% [markdown]
# ### Tableau des repartitions des **classes prédites** pour chaque **classe réelle**

# %%
df_pred = pd.DataFrame()
for c in Lcat:
            s = df_cross.loc[c].sort_values(ascending=False)[:5]
            df_temp = pd.DataFrame([{'Categorie':c,'predict':s.index[0],'pourc':s.values[0],'predict2':s.index[1],'pourc2':s.values[1],'predict3':s.index[2],'pourc3':s.values[2]}])
            df_pred = pd.concat([df_pred, df_temp], ignore_index=True)

# %%
df_pred
# Out:
#     Categorie  predict     pourc  predict2    pourc2  predict3    pourc3
# 0          10       10  0.455677      2705  0.155521      2403  0.119751
# 1          40       40  0.640159        10  0.053678        50  0.043738
# 2          50       50  0.849530      1280  0.034483        40  0.025078
# 3          60       60  0.905028        50  0.044693      2462  0.022346
# 4        1140     1140  0.614679      1280  0.196330        40  0.029358
# 5        1160     1160  0.865069        40  0.034048        10  0.027743
# 6        1180     1180  0.569444        40  0.069444      1281  0.062500
# 7        1280     1280  0.794411      1281  0.032934      1140  0.031936
# 8        1281     1281  0.463235      1280  0.284314      1302  0.049020
# 9        1300     1300  0.916415      1280  0.055388        50  0.004028
# 10       1301     1301  0.913580      1280  0.018519        10  0.012346
# 11       1302     1302  0.774319      1280  0.142023      2583  0.015564
# 12       1320     1320  0.774096      1280  0.054217      2060  0.031627
# 13       1560     1560  0.828802      2060  0.063444      1920  0.024169
# 14       1920     1920  0.903846      2060  0.040865      1560  0.031250
# 15       1940     1940  0.767296        10  0.031447      1320  0.025157
# 16       2060     2060  0.789691      1560  0.054639      2585  0.026804
# 17       2220     2220  0.668421      1302  0.068421      1320  0.057895
# 18       2280     2280  0.829857      2403  0.063666        10  0.054885
# 19       2403     2403  0.684703        10  0.110302      2280  0.072841
# 20       2462     2462  0.671096        50  0.139535        60  0.066445
# 21       2522     2522  0.893175      1280  0.018793      2403  0.015826
# 22       2582     2582  0.622889      1560  0.118199      2060  0.082552
# 23       2583     2583  0.954393      1302  0.013442      2585  0.008161
# 24       2585     2585  0.752137      1302  0.036325      2582  0.034188
# 25       2705     2705  0.676840        10  0.147217      2403  0.055655
# 26       2905     2905  1.000000      1920  0.000000      2705  0.000000

# %% [markdown]
# ### Tableau croisé

# %%
df_cross
# Out:
# predict          10        40        50        60        1140      1160  \
# prdtypecode
# 10           0.430793  0.052877  0.003110  0.003110  0.010886  0.021773
# 40           0.061630  0.671968  0.035785  0.003976  0.015905  0.019881
# 50           0.006270  0.021944  0.818182  0.000000  0.021944  0.003135
# 60           0.000000  0.022346  0.039106  0.882682  0.000000  0.000000
# 1140         0.014679  0.022018  0.009174  0.000000  0.741284  0.020183
# 1160         0.037831  0.020177  0.000000  0.000000  0.020177  0.846154
# 1180         0.013889  0.027778  0.006944  0.006944  0.090278  0.041667
# 1280         0.004990  0.010978  0.007984  0.000998  0.048902  0.002994
# 1281         0.017157  0.031863  0.012255  0.000000  0.009804  0.026961
# 1300         0.003021  0.002014  0.002014  0.000000  0.006042  0.000000
# 1301         0.006173  0.012346  0.000000  0.000000  0.000000  0.000000
# 1302         0.005837  0.000000  0.000000  0.000000  0.001946  0.001946
# 1320         0.006024  0.009036  0.003012  0.001506  0.001506  0.001506
# 1560         0.001007  0.000000  0.005035  0.000000  0.001007  0.000000
# 1920         0.001202  0.000000  0.000000  0.000000  0.000000  0.001202
# 1940         0.069182  0.018868  0.012579  0.000000  0.000000  0.000000
# 2060         0.000000  0.002062  0.007216  0.000000  0.004124  0.001031
# 2220         0.005263  0.015789  0.005263  0.000000  0.000000  0.000000
# 2280         0.040615  0.004391  0.000000  0.000000  0.005488  0.009879
# 2403         0.086368  0.011446  0.003122  0.000000  0.004162  0.015609
# 2462         0.003322  0.049834  0.102990  0.026578  0.009967  0.013289
# 2522         0.002967  0.000989  0.001978  0.000000  0.004946  0.000989
# 2582         0.000000  0.000000  0.003752  0.000000  0.001876  0.000000
# 2583         0.000960  0.000000  0.000000  0.000000  0.000000  0.000000
# 2585         0.004274  0.000000  0.008547  0.000000  0.000000  0.006410
# 2705         0.141831  0.026930  0.003591  0.000000  0.005386  0.007181
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          1180      1280      1281      1300      1301      1302  \
# prdtypecode
# 10           0.000000  0.015552  0.018663  0.001555  0.000000  0.010886
# 40           0.000000  0.021869  0.033797  0.000000  0.000000  0.007952
# 50           0.000000  0.031348  0.012539  0.009404  0.000000  0.003135
# 60           0.000000  0.000000  0.005587  0.000000  0.000000  0.000000
# 1140         0.005505  0.095413  0.014679  0.001835  0.000000  0.001835
# 1160         0.006305  0.007566  0.017654  0.000000  0.000000  0.001261
# 1180         0.493056  0.062500  0.062500  0.027778  0.000000  0.027778
# 1280         0.003992  0.764471  0.037924  0.016966  0.000000  0.028942
# 1281         0.009804  0.276961  0.514706  0.002451  0.000000  0.044118
# 1300         0.003021  0.059416  0.001007  0.900302  0.000000  0.004028
# 1301         0.000000  0.006173  0.024691  0.000000  0.901235  0.030864
# 1302         0.000000  0.099222  0.023346  0.001946  0.000000  0.803502
# 1320         0.000000  0.051205  0.004518  0.001506  0.000000  0.013554
# 1560         0.000000  0.005035  0.000000  0.000000  0.000000  0.008056
# 1920         0.000000  0.002404  0.000000  0.000000  0.000000  0.000000
# 1940         0.000000  0.031447  0.006289  0.031447  0.000000  0.018868
# 2060         0.000000  0.018557  0.003093  0.002062  0.000000  0.006186
# 2220         0.000000  0.010526  0.000000  0.005263  0.005263  0.000000
# 2280         0.000000  0.003293  0.002195  0.000000  0.000000  0.002195
# 2403         0.000000  0.008325  0.008325  0.000000  0.000000  0.004162
# 2462         0.003322  0.003322  0.009967  0.000000  0.000000  0.000000
# 2522         0.000000  0.024728  0.009891  0.000000  0.001978  0.008902
# 2582         0.000000  0.005629  0.000000  0.001876  0.000000  0.022514
# 2583         0.000000  0.001440  0.000480  0.000000  0.000960  0.010082
# 2585         0.000000  0.012821  0.000000  0.002137  0.000000  0.034188
# 2705         0.001795  0.003591  0.016158  0.000000  0.000000  0.005386
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          1320      1560      1920      1940      2060      2220  \
# prdtypecode
# 10           0.015552  0.001555  0.000000  0.001555  0.007776  0.001555
# 40           0.005964  0.001988  0.000000  0.000000  0.003976  0.003976
# 50           0.009404  0.000000  0.003135  0.000000  0.003135  0.000000
# 60           0.000000  0.000000  0.000000  0.000000  0.005587  0.000000
# 1140         0.003670  0.001835  0.003670  0.000000  0.012844  0.001835
# 1160         0.001261  0.001261  0.000000  0.000000  0.001261  0.000000
# 1180         0.013889  0.006944  0.006944  0.000000  0.013889  0.000000
# 1280         0.018962  0.001996  0.000998  0.000000  0.009980  0.003992
# 1281         0.004902  0.002451  0.000000  0.000000  0.000000  0.000000
# 1300         0.001007  0.001007  0.000000  0.000000  0.002014  0.000000
# 1301         0.012346  0.000000  0.000000  0.000000  0.000000  0.000000
# 1302         0.011673  0.007782  0.000000  0.000000  0.000000  0.001946
# 1320         0.784639  0.022590  0.019578  0.000000  0.030120  0.004518
# 1560         0.005035  0.849950  0.022155  0.000000  0.045317  0.000000
# 1920         0.013221  0.038462  0.908654  0.000000  0.024038  0.001202
# 1940         0.025157  0.012579  0.000000  0.691824  0.006289  0.012579
# 2060         0.017526  0.061856  0.030928  0.002062  0.776289  0.005155
# 2220         0.036842  0.047368  0.005263  0.005263  0.010526  0.736842
# 2280         0.002195  0.000000  0.000000  0.000000  0.001098  0.000000
# 2403         0.003122  0.000000  0.000000  0.000000  0.002081  0.001041
# 2462         0.000000  0.000000  0.000000  0.000000  0.003322  0.000000
# 2522         0.004946  0.013848  0.000989  0.000000  0.004946  0.000000
# 2582         0.011257  0.159475  0.011257  0.001876  0.054409  0.007505
# 2583         0.000480  0.002400  0.000960  0.000480  0.004801  0.000960
# 2585         0.012821  0.038462  0.002137  0.004274  0.032051  0.004274
# 2705         0.008977  0.005386  0.000000  0.000000  0.003591  0.001795
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          2280      2403      2462      2522      2582      2583  \
# prdtypecode
# 10           0.079316  0.185070  0.006221  0.006221  0.003110  0.006221
# 40           0.011928  0.027833  0.039761  0.003976  0.000000  0.000000
# 50           0.000000  0.003135  0.028213  0.015674  0.000000  0.000000
# 60           0.000000  0.000000  0.033520  0.000000  0.000000  0.000000
# 1140         0.005505  0.018349  0.012844  0.003670  0.000000  0.001835
# 1160         0.005044  0.012610  0.013871  0.003783  0.001261  0.001261
# 1180         0.000000  0.027778  0.034722  0.013889  0.000000  0.000000
# 1280         0.003992  0.008982  0.003992  0.009980  0.000000  0.001996
# 1281         0.002451  0.012255  0.014706  0.002451  0.002451  0.000000
# 1300         0.005035  0.002014  0.001007  0.000000  0.002014  0.001007
# 1301         0.000000  0.000000  0.006173  0.000000  0.000000  0.000000
# 1302         0.000000  0.001946  0.000000  0.005837  0.009728  0.011673
# 1320         0.007530  0.001506  0.001506  0.009036  0.006024  0.003012
# 1560         0.000000  0.001007  0.000000  0.010070  0.025176  0.003021
# 1920         0.000000  0.001202  0.000000  0.006010  0.000000  0.001202
# 1940         0.000000  0.000000  0.000000  0.018868  0.018868  0.000000
# 2060         0.003093  0.002062  0.001031  0.005155  0.027835  0.002062
# 2220         0.000000  0.000000  0.005263  0.000000  0.015789  0.000000
# 2280         0.822173  0.092206  0.000000  0.002195  0.000000  0.001098
# 2403         0.068678  0.745057  0.004162  0.008325  0.000000  0.002081
# 2462         0.006645  0.016611  0.744186  0.006645  0.000000  0.000000
# 2522         0.001978  0.024728  0.000989  0.880317  0.001978  0.000989
# 2582         0.001876  0.001876  0.000000  0.003752  0.628518  0.013133
# 2583         0.000480  0.000480  0.000480  0.000480  0.002400  0.960634
# 2585         0.002137  0.002137  0.002137  0.006410  0.034188  0.027778
# 2705         0.021544  0.071813  0.005386  0.001795  0.000000  0.001795
# 2905         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
# predict          2585      2705      2905
# prdtypecode
# 10           0.004666  0.111975  0.000000
# 40           0.001988  0.023857  0.001988
# 50           0.006270  0.000000  0.003135
# 60           0.005587  0.005587  0.000000
# 1140         0.000000  0.007339  0.000000
# 1160         0.000000  0.001261  0.000000
# 1180         0.006944  0.013889  0.000000
# 1280         0.004990  0.000000  0.000998
# 1281         0.004902  0.007353  0.000000
# 1300         0.003021  0.001007  0.000000
# 1301         0.000000  0.000000  0.000000
# 1302         0.009728  0.001946  0.000000
# 1320         0.013554  0.003012  0.000000
# 1560         0.018127  0.000000  0.000000
# 1920         0.000000  0.001202  0.000000
# 1940         0.025157  0.000000  0.000000
# 2060         0.018557  0.002062  0.000000
# 2220         0.089474  0.000000  0.000000
# 2280         0.000000  0.010977  0.000000
# 2403         0.000000  0.022893  0.001041
# 2462         0.000000  0.000000  0.000000
# 2522         0.005935  0.000989  0.000000
# 2582         0.069418  0.000000  0.000000
# 2583         0.010562  0.000480  0.000000
# 2585         0.762821  0.000000  0.000000
# 2705         0.001795  0.664273  0.000000
# 2905         0.000000  0.000000  1.000000

# %% [markdown]
# ### Tableau des 5 classes les plus prédites pour chaque classe réélle avec libellés

# %%
for c in Lcat:
    print(c,'   ------   ', catdict[c] )
    s=df_cross.loc[c].sort_values(ascending=False)[:5]
    for index, value in s.items():
        print(f"  : {index},  : {np.round(value*100,2)} % , {catdict[index]}")
# Out:
# 10    ------    livres
#   : 10,  : 43.08 % , livres
#   : 2403,  : 18.51 % , livres et bds
#   : 2705,  : 11.2 % , bds et livres
#   : 2280,  : 7.93 % , magazines
#   : 40,  : 5.29 % , jeux video pour pc et consoles
# 40    ------    jeux video pour pc et consoles
#   : 40,  : 67.2 % , jeux video pour pc et consoles
#   : 10,  : 6.16 % , livres
#   : 2462,  : 3.98 % , consoles de jeux video et jeux videos
#   : 50,  : 3.58 % ,  accesoires jeux video
#   : 1281,  : 3.38 % , jeux de societe/cartes
# 50    ------     accesoires jeux video
#   : 50,  : 81.82 % ,  accesoires jeux video
#   : 1280,  : 3.13 % , jouets, peluches, poupees
#   : 2462,  : 2.82 % , consoles de jeux video et jeux videos
#   : 1140,  : 2.19 % , produits derives “geeks” et figurines
#   : 40,  : 2.19 % , jeux video pour pc et consoles
# 60    ------    consoles de jeux video
#   : 60,  : 88.27 % , consoles de jeux video
#   : 50,  : 3.91 % ,  accesoires jeux video
#   : 2462,  : 3.35 % , consoles de jeux video et jeux videos
#   : 40,  : 2.23 % , jeux video pour pc et consoles
#   : 2060,  : 0.56 % , lampes et accesoires decoration pour maison
# 1140    ------    produits derives “geeks” et figurines
#   : 1140,  : 74.13 % , produits derives “geeks” et figurines
#   : 1280,  : 9.54 % , jouets, peluches, poupees
#   : 40,  : 2.2 % , jeux video pour pc et consoles
#   : 1160,  : 2.02 % , cartes collectionables
#   : 2403,  : 1.83 % , livres et bds
# 1160    ------    cartes collectionables
#   : 1160,  : 84.62 % , cartes collectionables
#   : 10,  : 3.78 % , livres
#   : 1140,  : 2.02 % , produits derives “geeks” et figurines
#   : 40,  : 2.02 % , jeux video pour pc et consoles
#   : 1281,  : 1.77 % , jeux de societe/cartes
# 1180    ------    figurines collectionables pour jeux de societe
#   : 1180,  : 49.31 % , figurines collectionables pour jeux de societe
#   : 1140,  : 9.03 % , produits derives “geeks” et figurines
#   : 1280,  : 6.25 % , jouets, peluches, poupees
#   : 1281,  : 6.25 % , jeux de societe/cartes
#   : 1160,  : 4.17 % , cartes collectionables
# 1280    ------    jouets, peluches, poupees
#   : 1280,  : 76.45 % , jouets, peluches, poupees
#   : 1140,  : 4.89 % , produits derives “geeks” et figurines
#   : 1281,  : 3.79 % , jeux de societe/cartes
#   : 1302,  : 2.89 % , jeux d'exterieur
#   : 1320,  : 1.9 % , sacs pour femmes et accesore petite enfance
# 1281    ------    jeux de societe/cartes
#   : 1281,  : 51.47 % , jeux de societe/cartes
#   : 1280,  : 27.7 % , jouets, peluches, poupees
#   : 1302,  : 4.41 % , jeux d'exterieur
#   : 40,  : 3.19 % , jeux video pour pc et consoles
#   : 1160,  : 2.7 % , cartes collectionables
# 1300    ------    Petites voitures (jouets) et maquettes
#   : 1300,  : 90.03 % , Petites voitures (jouets) et maquettes
#   : 1280,  : 5.94 % , jouets, peluches, poupees
#   : 1140,  : 0.6 % , produits derives “geeks” et figurines
#   : 2280,  : 0.5 % , magazines
#   : 1302,  : 0.4 % , jeux d'exterieur
# 1301    ------    accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
#   : 1301,  : 90.12 % , accesoires pour petis enfants/bebes et mobilier de jeu (flechettes, billard, babyfoot)
#   : 1302,  : 3.09 % , jeux d'exterieur
#   : 1281,  : 2.47 % , jeux de societe/cartes
#   : 1320,  : 1.23 % , sacs pour femmes et accesore petite enfance
#   : 40,  : 1.23 % , jeux video pour pc et consoles
# 1302    ------    jeux d'exterieur
#   : 1302,  : 80.35 % , jeux d'exterieur
#   : 1280,  : 9.92 % , jouets, peluches, poupees
#   : 1281,  : 2.33 % , jeux de societe/cartes
#   : 2583,  : 1.17 % , accesoires de piscine
#   : 1320,  : 1.17 % , sacs pour femmes et accesore petite enfance
# 1320    ------    sacs pour femmes et accesore petite enfance
#   : 1320,  : 78.46 % , sacs pour femmes et accesore petite enfance
#   : 1280,  : 5.12 % , jouets, peluches, poupees
#   : 2060,  : 3.01 % , lampes et accesoires decoration pour maison
#   : 1560,  : 2.26 % , Mobilier et produits decoration/rangement pour la maison
#   : 1920,  : 1.96 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
# 1560    ------    Mobilier et produits decoration/rangement pour la maison
#   : 1560,  : 84.99 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 4.53 % , lampes et accesoires decoration pour maison
#   : 2582,  : 2.52 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1920,  : 2.22 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 2585,  : 1.81 % , outillage et accesoires pour jardinage
# 1920    ------    linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 1920,  : 90.87 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 1560,  : 3.85 % , Mobilier et produits decoration/rangement pour la maison
#   : 2060,  : 2.4 % , lampes et accesoires decoration pour maison
#   : 1320,  : 1.32 % , sacs pour femmes et accesore petite enfance
#   : 2522,  : 0.6 % , produits de papeterie et rangement bureau
# 1940    ------    nouriture (cafes,infusions,conserves, epices,etc)
#   : 1940,  : 69.18 % , nouriture (cafes,infusions,conserves, epices,etc)
#   : 10,  : 6.92 % , livres
#   : 1280,  : 3.14 % , jouets, peluches, poupees
#   : 1300,  : 3.14 % , Petites voitures (jouets) et maquettes
#   : 2585,  : 2.52 % , outillage et accesoires pour jardinage
# 2060    ------    lampes et accesoires decoration pour maison
#   : 2060,  : 77.63 % , lampes et accesoires decoration pour maison
#   : 1560,  : 6.19 % , Mobilier et produits decoration/rangement pour la maison
#   : 1920,  : 3.09 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 2582,  : 2.78 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2585,  : 1.86 % , outillage et accesoires pour jardinage
# 2220    ------    accesoires mascots/pets
#   : 2220,  : 73.68 % , accesoires mascots/pets
#   : 2585,  : 8.95 % , outillage et accesoires pour jardinage
#   : 1560,  : 4.74 % , Mobilier et produits decoration/rangement pour la maison
#   : 1320,  : 3.68 % , sacs pour femmes et accesore petite enfance
#   : 2582,  : 1.58 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
# 2280    ------    magazines
#   : 2280,  : 82.22 % , magazines
#   : 2403,  : 9.22 % , livres et bds
#   : 10,  : 4.06 % , livres
#   : 2705,  : 1.1 % , bds et livres
#   : 1160,  : 0.99 % , cartes collectionables
# 2403    ------    livres et bds
#   : 2403,  : 74.51 % , livres et bds
#   : 10,  : 8.64 % , livres
#   : 2280,  : 6.87 % , magazines
#   : 2705,  : 2.29 % , bds et livres
#   : 1160,  : 1.56 % , cartes collectionables
# 2462    ------    consoles de jeux video et jeux videos
#   : 2462,  : 74.42 % , consoles de jeux video et jeux videos
#   : 50,  : 10.3 % ,  accesoires jeux video
#   : 40,  : 4.98 % , jeux video pour pc et consoles
#   : 60,  : 2.66 % , consoles de jeux video
#   : 2403,  : 1.66 % , livres et bds
# 2522    ------    produits de papeterie et rangement bureau
#   : 2522,  : 88.03 % , produits de papeterie et rangement bureau
#   : 2403,  : 2.47 % , livres et bds
#   : 1280,  : 2.47 % , jouets, peluches, poupees
#   : 1560,  : 1.38 % , Mobilier et produits decoration/rangement pour la maison
#   : 1281,  : 0.99 % , jeux de societe/cartes
# 2582    ------    mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 2582,  : 62.85 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1560,  : 15.95 % , Mobilier et produits decoration/rangement pour la maison
#   : 2585,  : 6.94 % , outillage et accesoires pour jardinage
#   : 2060,  : 5.44 % , lampes et accesoires decoration pour maison
#   : 1302,  : 2.25 % , jeux d'exterieur
# 2583    ------    accesoires de piscine
#   : 2583,  : 96.06 % , accesoires de piscine
#   : 2585,  : 1.06 % , outillage et accesoires pour jardinage
#   : 1302,  : 1.01 % , jeux d'exterieur
#   : 2060,  : 0.48 % , lampes et accesoires decoration pour maison
#   : 1560,  : 0.24 % , Mobilier et produits decoration/rangement pour la maison
# 2585    ------    outillage et accesoires pour jardinage
#   : 2585,  : 76.28 % , outillage et accesoires pour jardinage
#   : 1560,  : 3.85 % , Mobilier et produits decoration/rangement pour la maison
#   : 2582,  : 3.42 % , mobilier d'exterieur et accesoires (parasols,pots,tentes,etc)
#   : 1302,  : 3.42 % , jeux d'exterieur
#   : 2060,  : 3.21 % , lampes et accesoires decoration pour maison
# 2705    ------    bds et livres
#   : 2705,  : 66.43 % , bds et livres
#   : 10,  : 14.18 % , livres
#   : 2403,  : 7.18 % , livres et bds
#   : 40,  : 2.69 % , jeux video pour pc et consoles
#   : 2280,  : 2.15 % , magazines
# 2905    ------    Jeu En téléchargement
#   : 2905,  : 100.0 % , Jeu En téléchargement
#   : 1920,  : 0.0 % , linge de maison (cousins, rideaux, serviettes, nappes, draps)
#   : 2705,  : 0.0 % , bds et livres
#   : 2585,  : 0.0 % , outillage et accesoires pour jardinage
#   : 2583,  : 0.0 % , accesoires de piscine

# %% [markdown]
# ### Matrice de confusion

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test_original, test_pred_original)
print(cm[:10,:10])
print('*************************************************')
print(cm[10:20,10:20])
print('*************************************************')
print(cm[20:,20:])
# Out:
# [[277  34   2   2   7  14   0  10  12   1]
#  [ 31 338  18   2   8  10   0  11  17   0]
#  [  2   7 261   0   7   1   0  10   4   3]
#  [  0   4   7 158   0   0   0   0   1   0]
#  [  8  12   5   0 404  11   3  52   8   1]
#  [ 30  16   0   0  16 671   5   6  14   0]
#  [  2   4   1   1  13   6  71   9   9   4]
#  [  5  11   8   1  49   3   4 766  38  17]
#  [  7  13   5   0   4  11   4 113 210   1]
#  [  3   2   2   0   6   0   3  59   1 894]]
# *************************************************
# [[146   5   2   0   0   0   0   0   0   0]
#  [  0 413   6   4   0   0   0   1   0   1]
#  [  0   9 521  15  13   0  20   3   5   1]
#  [  0   8   5 844  22   0  45   0   0   1]
#  [  0   0  11  32 756   0  20   1   0   1]
#  [  0   3   4   2   0 110   1   2   0   0]
#  [  0   6  17  60  30   2 753   5   3   2]
#  [  1   0   7   9   1   1   2 140   0   0]
#  [  0   2   2   0   0   0   1   0 749  84]
#  [  0   4   3   0   0   0   2   1  66 716]]
# *************************************************
# [[ 224    2    0    0    0    0    0]
#  [   1  890    2    1    6    1    0]
#  [   0    2  335    7   37    0    0]
#  [   1    1    5 2001   22    1    0]
#  [   1    3   16   13  357    0    0]
#  [   3    1    0    1    1  370    0]
#  [   0    0    0    0    0    0  146]]

# %%
fig, ax = plt.subplots(figsize=(10,10))
cm_normalized = cm.astype('float') / (cm.sum(axis=1)[:, np.newaxis])
#cm_normalized=cm.div(cm.sum(axis=1), axis=0)
cax = ax.matshow(cm_normalized, cmap='Reds')
plt.xticks(range(27),catdict,rotation=90)
plt.yticks(range(27),catdict,rotation=0)
plt.show()

# %%
import itertools



# Calcul de la matrice de confusion
cnf_matrix = confusion_matrix(y_test_original, test_pred_original, labels=sorted(list(set(y_test_original))))

# Définition des classes
classes = sorted(list(set(y_test_original)))

# Création et configuration de la figure
plt.figure(figsize=(15, 15))
plt.imshow(cnf_matrix, interpolation='nearest', cmap='Blues')
plt.title("Matrice de confusion")
plt.colorbar()

# Configuration des ticks
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=90)
plt.yticks(tick_marks, classes)

# Annotation de chaque cellule de la matrice de confusion
for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
    plt.text(j, i, cnf_matrix[i, j],
             horizontalalignment="center",
             color="white" if cnf_matrix[i, j] > (cnf_matrix.max() / 2) else "black")

# Labels pour les axes
plt.ylabel('Vrais labels')
plt.xlabel('Labels prédits')

# Affichage de la matrice de confusion
plt.show()

# %% [markdown]
# ## Etude des catégories 10 ; 2280 ; 2403 ; 2705

# %%
df_livres=df_test[df_test['prdtypecode'].isin([10,2280,2403,2705])]
df_livres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3072 entries, 58440 to 46826
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tokenized    3072 non-null   object
#  1   prdtypecode  3072 non-null   int64
#  2   predict      3072 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 96.0+ KB

# %%
df_livres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3072 entries, 58440 to 46826
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tokenized    3072 non-null   object
#  1   prdtypecode  3072 non-null   int64
#  2   predict      3072 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 96.0+ KB

# %% [markdown]
# ### Tableau des 5 classes les plus prédites pour chaque classe réélle

# %%
for c in [10,2280,2403,2705]:
    print(c,'   ------   ', catdict[c] )
    print(df_livres[df_livres['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 10    ------    livres
# predict
# 10      0.430793
# 2403    0.185070
# 2705    0.111975
# 2280    0.079316
# 40      0.052877
# Name: proportion, dtype: float64
# 2280    ------    magazines
# predict
# 2280    0.822173
# 2403    0.092206
# 10      0.040615
# 2705    0.010977
# 1160    0.009879
# Name: proportion, dtype: float64
# 2403    ------    livres et bds
# predict
# 2403    0.745057
# 10      0.086368
# 2280    0.068678
# 2705    0.022893
# 1160    0.015609
# Name: proportion, dtype: float64
# 2705    ------    bds et livres
# predict
# 2705    0.664273
# 10      0.141831
# 2403    0.071813
# 40      0.026930
# 2280    0.021544
# Name: proportion, dtype: float64

# %%
print(df_livres.info())
df_livres.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3072 entries, 58440 to 46826
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tokenized    3072 non-null   object
#  1   prdtypecode  3072 non-null   int64
#  2   predict      3072 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 96.0+ KB
# None
#                                                                                                  tokenized  \
# 58440                                                          [miroir, sprint, n°, campionnissimo, valet]
# 1068   [dictionnaire, etymologique, roman, derom, second, volume, dictionnaire, tymologique, roman, rom...
# 48464                                                                       [compte, rebours, douze, mois]
# 22835                                                                                           [lot, sas]
# 37938  [lot, premiers, tomes, etoiles, hommes, enseignement, christ, maitreya, richard, vitrac, marie, ...
#
#        prdtypecode  predict
# 58440         2280     2280
# 1068          2705     2403
# 48464         2403     2705
# 22835         2403     2403
# 37938         2403     2403

# %% [markdown]
# ### Répartition des 20 mots les plus présents sur l'ensemble de ces catégories

# %%
import pandas as pd
from collections import Counter

# Étape 1 : Identifier les 20 mots les plus fréquents
all_words = sum(df_livres['tokenized'].tolist(), [])
global_word_counts = Counter(all_words)
top_20_words = global_word_counts.most_common(20)

# Étape 2 : Calculer le nombre d'occurrences de chaque mot pour chaque classe et globalement
# Initialiser les données pour le DataFrame
data = {"Word": [word for word, count in top_20_words], "Total": [count for word, count in top_20_words]}
class_ids = df_livres['prdtypecode'].unique()

# Calculer les occurrences par classe pour chaque mot
for class_id in class_ids:
    data[class_id] = []
    for word, _ in top_20_words:
        word_count = sum(row.count(word) for row in df_livres[df_livres['prdtypecode'] == class_id]['tokenized'])
        data[class_id].append(word_count)

# Étape 3 : Créer le DataFrame
df_word_counts = pd.DataFrame(data)
df_word_counts.set_index("Word", inplace=True)

# Afficher le DataFrame
print(df_word_counts)
df_total_livres=df_word_counts
# Out:
#             Total  2280  2705  2403  10
# Word
# n°            962   763     4   151  44
# lot           426     0     0   426   0
# vie           231    33   151    29  18
# livres        221     5    13   189  14
# monde         179    54   106    14   5
# tome          170     6    58    66  40
# france        160    73    35    33  19
# livre         157     3    83    34  37
# cette         149     3   142     2   2
# histoire      141    24    70    28  19
# temps         108     9    74    14  11
# paris         102    55    26    15   6
# collection    100    10    16    58  16
# jean           97    39    21    25  12
# journal        96    66     7    16   7
# homme          96     6    77     6   7
# edition        96     4     9    40  43
# bien           95     7    85     2   1
# deux           92    19    54    14   5
# entre          92     6    73     7   6

# %%
fig, ax = plt.subplots(figsize=(2,20))
cax = ax.matshow(df_total_livres.iloc[0:20], cmap = 'coolwarm')
plt.xticks(range(5),(df_total_livres.columns.tolist()),rotation=45)
plt.yticks(range(20),df_total_livres.iloc[0:20].index,rotation=0)
plt.show()

# %% [markdown]
# ## Etude des catégories 1280,1281

# %%
df_jouets=df_test[df_test['prdtypecode'].isin([1280,1281])]

# %% [markdown]
# ### Tableau des 5 classes les plus prédites pour chaque classe réélle

# %%
for c in [1280,1281]:
    print(c,'   ------   ', catdict[c] )
    print(df_jouets[df_jouets['prdtypecode']==c]['predict'].value_counts(normalize=True)[:5])
# Out:
# 1280    ------    jouets, peluches, poupees
# predict
# 1280    0.764471
# 1140    0.048902
# 1281    0.037924
# 1302    0.028942
# 1320    0.018962
# Name: proportion, dtype: float64
# 1281    ------    jeux de societe/cartes
# predict
# 1281    0.514706
# 1280    0.276961
# 1302    0.044118
# 40      0.031863
# 1160    0.026961
# Name: proportion, dtype: float64

# %% [markdown]
# ### Répartition des 20 mots les plus présents sur l'ensemble de ces catégories

# %%
import pandas as pd
from collections import Counter

# Étape 1 : Identifier les 20 mots les plus fréquents
all_words = sum(df_jouets['tokenized'].tolist(), [])
global_word_counts = Counter(all_words)
top_20_words = global_word_counts.most_common(20)

# Étape 2 : Calculer le nombre d'occurrences de chaque mot pour chaque classe et globalement
# Initialiser les données pour le DataFrame
data = {"Word": [word for word, count in top_20_words], "Total": [count for word, count in top_20_words]}
class_ids = df_jouets['prdtypecode'].unique()

# Calculer les occurrences par classe pour chaque mot
for class_id in class_ids:
    data[class_id] = []
    for word, _ in top_20_words:
        word_count = sum(row.count(word) for row in df_jouets[df_jouets['prdtypecode'] == class_id]['tokenized'])
        data[class_id].append(word_count)

# Étape 3 : Créer le DataFrame
df_word_counts = pd.DataFrame(data)
df_word_counts.set_index("Word", inplace=True)

# Afficher le DataFrame
df_word_counts
df_total_livres=df_word_counts
df_word_counts
# Out:
#           Total  1280  1281
# Word
# enfants    1350   940   410
# jouet       594   445   149
# jouets      593   435   158
# bebe        546   416   130
# taille      529   423   106
# haute       432   337    95
# jeu         415   184   231
# couleur     372   289    83
# toy         372   290    82
# qualite     371   276    95
# etre        367   289    78
# cadeau      345   244   101
# poupee      336   247    89
# non         305   206    99
# voiture     299   263    36
# bois        286   194    92
# materiel    285   227    58
# jouer       275   188    87
# produit     273   213    60
# batterie    264   241    23

# %%
fig, ax = plt.subplots(figsize=(2,20))
cax = ax.matshow(df_total_livres.iloc[0:20], cmap = 'coolwarm')
plt.xticks(range(3),(df_total_livres.columns.tolist()),rotation=45)
plt.yticks(range(20),df_total_livres.iloc[0:20].index,rotation=0)
plt.show()
