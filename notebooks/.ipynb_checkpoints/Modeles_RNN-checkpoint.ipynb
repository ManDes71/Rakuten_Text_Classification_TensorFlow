# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf


gpus = tf.config.experimental.list_physical_devices('GPU')

if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)

# %%
import configparser
import sys
sys.path.append('../src')
import Bibli_DataScience_3_3 as ds
config = configparser.ConfigParser()
config.read('Rakuten_config.ini')
# Out:
# section :  ['DOSSIER', 'FICHIER']
# []

# %%
import spacy
print(spacy.__version__)
# Out:
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 92.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from fr-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.2.0)
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 109.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting de-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.7.0/de_core_news_sm-3.7.0-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from de-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.26.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->de-core-news-sm==3.7.0) (1.2.0)
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 33.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from es-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.2.0)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# Collecting it-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-3.7.0/it_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 34.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from it-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.26.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->it-core-news-sm==3.7.0) (1.2.0)
# Installing collected packages: it-core-news-sm
# Successfully installed it-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('it_core_news_sm')
# Collecting nl-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/nl_core_news_sm-3.7.0/nl_core_news_sm-3.7.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 32.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from nl-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.26.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->nl-core-news-sm==3.7.0) (1.2.0)
# Installing collected packages: nl-core-news-sm
# Successfully installed nl-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('nl_core_news_sm')
# Collecting ca-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ca_core_news_sm-3.7.0/ca_core_news_sm-3.7.0-py3-none-any.whl (19.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.6/19.6 MB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from ca-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (1.26.3)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->ca-core-news-sm==3.7.0) (1.2.0)
# Installing collected packages: ca-core-news-sm
# Successfully installed ca-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ca_core_news_sm')

# %%
import imp
imp.reload(ds)
imp.reload(rnn)
# Out:
# section :  ['DOSSIER', 'FICHIER']
# <module 'RNN_DataScience' from '/content/Rakuten_Text_Classification_TensorFlow/src/RNN_DataScience.py'>

# %% [markdown]
# Ce notebook fait partie d'un ensemble de sous-projets dont le resultat représente le **projet Rakuten** que j'ai réalisé pour mon diplôme de data Scientist chez Datascientest.com.
# Ce projet consiste en la classification à grande échelle des données de         produits multimodales (texte et image) en type de produits.
# Ce repositery est la partie **Réseaux de Neurones Récurrents** et ne traite que de la partie texte.
# Il fait suite à la partie **Machine Learning**
# Il utilise la bibliothèque **Bibli_DataScience** commune à l'ensemble du projet et la bibbliothèque **RNN_DataScience.py** propre à cette partie.
# D'autres dépots viendront, à savoir  :
#
#
# *   La partie image  traitée par des réseaux convolutifs
# *   Une quatrième partie qui est une syntèse par le media Streamlit

# %% [markdown]
# Ce notebook traite du Traitement automatique du langage naturel (natural language processing ou NLP) et teste plusieurs approches.
#
# explication de la bibliothèque **RNN_DataScience.py**  :
#
# J'ai construit tout le code sur un modèle objet.
# Chaque modèle est une classe et hérite d'une classe générale **DS_RNN**
#
# *   Une `tokenisation` simple suivie d'une couche d'Embedding de tensorFlow -> classe **RNN_EMBEDDING**
# *   Une `tokenisation` puis une racinisation (`stemming`) suivie d'une couche d'Embedding de tensorFlow -> classe **RNN_STEMMER**
# *   Une tokenisation puis une `lemmatisation` en utilisant `NLTK` suivie d'une couche d'Embedding de tensorFlow -> classe **RNN_LEMMER**
# *   Une tokenisation puis une `lemmatisation` en utilisant `SPACY` suivie d'une couche d'Embedding de tensorFlow -> classe **RNN_SPACY**
#
# Ces 4 modèles utilisent un réseau de neurones comportant une couche GRU.
#
# Un cinquième modèle fait partie d'un notebook différent car son architecture est un peu différente (Word2VEC) : Modele_RNN_Word2Vec.ipynb
#
# Pour tous les modèles on utilise le même préprocessing de base :

# %% [markdown]
# ## ETAPE 1 : Passage en minuscule
# Dans un premier temps, nous transformons les majuscules en minuscules car les étapes suivantes sont sensibles à la casse
# ## ETAPE 2: Tokenisation
#  Il s’agit de décomposer une phrase, et donc un document, en tokens. Un token est un élément correspondant à un mot ou une ponctuation, cependant de nombreux cas ne sont pas triviaux à traiter :
# Les mots avec un trait d’union, exemple : peut être et peut-être qui ont des significations très différentes ;
# Les dates et heures qui peuvent être séparées par des points, des slashs, des deux points ;
# Les apostrophes ;
# Les caractères spéciaux : émoticônes, formules mathématiques.
# ## ETAPE 3: Retrait des stopwords
# Ensuite, nous retirons les mots appartenant aux stopwords. Il s’agit de listes de mots définies au préalable soit par l’utilisateur soit dans des librairies existantes. Ces listes se composent de mots qui n’apportent aucune information, qui sont en général très courants et donc présents dans la plupart des documents, par exemple : je, nous, avoir (le verbe et ses conjugaisons). La suppression de ces stopwords permet de ne pas polluer les représentations des documents afin qu’elle ne contienne que les mots représentatifs et significatifs. Ce “nettoyage” du texte peut aussi s’accompagner de la suppression d’autres éléments comme les nombres, les dates, la ponctuation etc.

# %% [markdown]
# # Modèle 1 : classe RNN_EMBEDDING
#
# #### Une tokenisation simple suivie d'une couche d'Embedding de tensorFlow
# TOKENISATION + EMBEDDING

# %% [markdown]
# #####  instanciation du modèle **RNN_EMBEDDING**

# %%
emb = rnn.RNN_EMBEDDING("EMBEDDING")
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# #### **RNN_EMBEDDING** : Lancement de l'entrainement
# Récupération des Poids du Modèle, des précisions, des pertes et des prédictions.

# %%
# entrainement du modèle
train_acc,val_acc,tloss,tvalloss = emb.fit_modele(5,savefics=True,Train='Save')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67932 entries, 83256 to 20596
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67932 non-null  int64
#  1   designation     67932 non-null  object
#  2   description     44084 non-null  object
#  3   productid       67932 non-null  int64
#  4   imageid         67932 non-null  int64
#  5   PAYS_LANGUE     67932 non-null  object
#  6   RATIO_LANGUE    67932 non-null  float64
#  7   ORIGINE_LANGUE  67932 non-null  object
#  8   pays_design     67932 non-null  object
#  9   Ratio_design    67932 non-null  float64
#  10  pays_descr      44033 non-null  object
#  11  Ratio_descr     44033 non-null  float64
#  12  descr_NaN       67932 non-null  bool
#  13  nom_image       67932 non-null  object
#  14  filepath        67932 non-null  object
#  15  phrases         67932 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(9)
# memory usage: 8.4+ MB
# None
# etape 1/6
# etape 2/6
# etape 3/6
# Sauvegarde de jeu d'entrainement
# save y_train_avant.shape  (67932,)
# self.EMBEDDING_DIM 300
# suite
# (67932, 27)
# (16984, 27)
# vocab_size :  112071
# Sauvegarde de jeu pour la concatenation
# Epoch 1/5
# 2123/2123 [==============================] - 1858s 874ms/step - loss: 1.2179 - accuracy: 0.6472 - val_loss: 0.7086 - val_accuracy: 0.7939 - lr: 0.0010
# Epoch 2/5
# 2123/2123 [==============================] - 1758s 828ms/step - loss: 0.4984 - accuracy: 0.8555 - val_loss: 0.6830 - val_accuracy: 0.8148 - lr: 0.0010
# Epoch 3/5
# 2123/2123 [==============================] - 1735s 817ms/step - loss: 0.2707 - accuracy: 0.9220 - val_loss: 0.7675 - val_accuracy: 0.8095 - lr: 0.0010
# Epoch 4/5
# 2123/2123 [==============================] - 1779s 838ms/step - loss: 0.1535 - accuracy: 0.9563 - val_loss: 0.8451 - val_accuracy: 0.8096 - lr: 0.0010
# Epoch 5/5
# 2123/2123 [==============================] - 1763s 830ms/step - loss: 0.1054 - accuracy: 0.9705 - val_loss: 0.9384 - val_accuracy: 0.8054 - lr: 0.0010
# 531/531 [==============================] - 71s 133ms/step
# 2123/2123 [==============================] - 282s 133ms/step
# 531/531 [==============================] - 71s 133ms/step
# Sauvegarde de jeu pour la concatenation
# Sauvegarde de jeu du label encoder
# Sauvegarde du model
# EMBEDDING_weight
# /content/Rakuten_Text_Classification_TensorFlow/input/EMBEDDING_weight.h5
# Sauvegarde du tokenizer
# y_test_original2[:5]  [1301 1140 2583 2280 2403]
# Sauvegarde de jeu du label encoder
# EMBEDDING_weight
# /content/Rakuten_Text_Classification_TensorFlow/input/EMBEDDING_weight.h5

# %% [markdown]
# #### **RNN_EMBEDDING** : Optionnel : Récupération des données

# %%
"""
# RECUPERATION

train_acc,val_acc,tloss,tvalloss = rnn.restore_fit_arrays()
y_orig,y_pred = rnn.restore_predict_arrays()
df_pred = rnnt.restore_predict_dataframe()
"""

# %% [markdown]
# #### **RNN_EMBEDDING** : Affichage des precisions et des pertes par époque

# %%
ds.plot_fit(train_acc,val_acc,tloss,tvalloss)

# %% [markdown]
# #### **RNN_EMBEDDING** : Affichage des 3 principales prédictions par catégorie
# Tableau des repartitions des **classes prédites** pour chaque **classe réelle**

# %%
df_pred = emb.get_df_pred()
df_pred
# Out:
#     Categorie  predict     pourc  predict2    pourc2  predict3    pourc3
# 0          10       10  0.365971      2705  0.192616      2403  0.158909
# 1          40       40  0.701195      2462  0.065737      2705  0.041833
# 2          50       50  0.851190      2462  0.050595        40  0.023810
# 3          60       60  0.795181      2462  0.126506        50  0.042169
# 4        1140     1140  0.726592      1280  0.059925      1160  0.041199
# 5        1160     1160  0.907712      2705  0.018963        10  0.012642
# 6        1180     1180  0.496732      1140  0.130719        10  0.052288
# 7        1280     1280  0.708419      1281  0.082136      1140  0.057495
# 8        1281     1281  0.570048      1280  0.142512      1160  0.053140
# 9        1300     1300  0.937562      1280  0.023786        40  0.007929
# 10       1301     1301  0.875776      1281  0.037267      2060  0.018634
# 11       1302     1302  0.761044      1280  0.066265      1281  0.030120
# 12       1320     1320  0.782407      1280  0.049383      2060  0.040123
# 13       1560     1560  0.839409      2060  0.057143      2582  0.034483
# 14       1920     1920  0.910569      2060  0.033682      1560  0.027875
# 15       1940     1940  0.701863      2582  0.055901      2060  0.049689
# 16       2060     2060  0.834835      1560  0.056056      1920  0.021021
# 17       2220     2220  0.654545      2582  0.054545      1280  0.048485
# 18       2280     2280  0.817227      2403  0.100840        10  0.030462
# 19       2403     2403  0.751832      2280  0.064921        10  0.055497
# 20       2462     2462  0.746479        40  0.077465        50  0.056338
# 21       2522     2522  0.896794      1560  0.027054      2403  0.015030
# 22       2582     2582  0.729730      2060  0.079151      1560  0.073359
# 23       2583     2583  0.976004      2585  0.005387      1560  0.002938
# 24       2585     2585  0.797595      2582  0.060120      2583  0.030060
# 25       2705     2705  0.742754        10  0.117754      2403  0.059783
# 26       2905     2905  1.000000      1920  0.000000      2705  0.000000

# %% [markdown]
# #### **RNN_EMBEDDING** : Rapport de classification
# Ce rapport inclut des métriques comme la précision, le rappel (recall), le score F1 et le support pour chaque classe individuelle :
#
# 1. Précision (**Precision**) : Le ratio des prédictions correctes pour chaque classe par rapport à toutes les prédictions faites pour cette classe.
# 2. Rappel (**Recall**) : Le ratio des prédictions correctes pour chaque classe par rapport au nombre total d'instances réelles de cette classe.
# 3. **Score F1** : La moyenne harmonique de la précision et du rappel, fournissant une mesure unique de la performance qui équilibre les deux.
# 4. **Support** : Le nombre d'occurrences réelles de chaque classe dans l'ensemble de test.

# %%
y_orig = emb.get_y_orig()
y_pred = emb.get_y_pred()
_,_ = ds.get_classification_report(y_orig, y_pred)
# Out:
# Précision de la prédiction: 80.81723975506358 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.53      0.37      0.43       623
#           40       0.73      0.70      0.71       502
#           50       0.79      0.85      0.82       336
#           60       0.92      0.80      0.85       166
#         1140       0.75      0.73      0.74       534
#         1160       0.79      0.91      0.85       791
#         1180       0.72      0.50      0.59       153
#         1280       0.72      0.71      0.72       974
#         1281       0.60      0.57      0.58       414
#         1300       0.96      0.94      0.95      1009
#         1301       0.92      0.88      0.90       161
#         1302       0.88      0.76      0.82       498
#         1320       0.81      0.78      0.80       648
#         1560       0.80      0.84      0.82      1015
#         1920       0.90      0.91      0.91       861
#         1940       0.96      0.70      0.81       161
#         2060       0.77      0.83      0.80       999
#         2220       0.90      0.65      0.76       165
#         2280       0.84      0.82      0.83       952
#         2403       0.68      0.75      0.72       955
#         2462       0.64      0.75      0.69       284
#         2522       0.93      0.90      0.91       998
#         2582       0.75      0.73      0.74       518
#         2583       0.97      0.98      0.97      2042
#         2585       0.77      0.80      0.78       499
#         2705       0.58      0.74      0.65       552
#         2905       0.98      1.00      0.99       174
#
#     accuracy                           0.81     16984
#    macro avg       0.80      0.77      0.78     16984
# weighted avg       0.81      0.81      0.81     16984

# %% [markdown]
# #### **RNN_EMBEDDING** : Génération et Affichage de la Matrice de Confusion
# 1. La **matrice de confusion** fournit une représentation visuelle des performances du modèle, montrant non seulement les bonnes classifications
# mais aussi les erreurs (**faux positifs** et **faux négatifs**).
# 2. En identifiant où le modèle a échoué (c.-à-d., les cellules non-diagonales de la matrice), on peut cibler les améliorations à apporter
# au modèle ou aux données d'entraînement.
# 3. Analyser la matrice de confusion permet d'identifier des classes spécifiques qui sont souvent confondues, ce qui peut indiquer un besoin d'ajustement des caractéristiques d'entrée ou d'ajout de données supplémentaires pour ces classes.

# %%
ds.show_confusion_matrix(y_orig, y_pred)

# %% [markdown]
# ## ETAPE 4 : Groupement sémantique
# Dès lors, nous disposons pour chaque document d’une liste “nettoyée” de mots porteurs de sens et séparés en tokens. Mais un mot peut être écrit au pluriel, au singulier ou avec différents accords et les verbes peuvent être conjugués à différents temps et personnes.
# Nous devons donc réduire les différences grammaticales des mots en trouvant des formes communes. Pour ce faire, nous disposons de deux méthodes distinctes :
# La stemmatisation, qui ne prend pas en compte le contexte de la phrase
# La lemmatisation, qui prend en compte le contexte
# ### ETAPE 4.1 : La stemmatisation
# La stemmatisation (ou racinisation) réduit les mots à leur radical ou racine.

# %% [markdown]
# # Modèle 2 : classe RNN_STEMMER
#
# ### Une tokenisation puis une racinisation (stemming) suivie d'une couche d'Embedding de tensorFlow
# TOKENISATION + STEMMISATION + EMBEDDING

# %% [markdown]
# #### Chargement des Modules Personnalisés
# On ajoute un chemin vers les modules personnalisés (Bibli_DataScience_3_3,RNN_DataScience ) pour charger des fonctions ou classes spécifiques nécessaires à l'analyse.

# %%
import Bibli_DataScience_3_3 as ds
import RNN_DataScience as rnn

# %%
import imp
imp.reload(ds)
imp.reload(rnn)
# Out:
# section :  ['DOSSIER', 'FICHIER']
# <module 'RNN_DataScience' from '/content/Rakuten_Text_Classification_TensorFlow/src/RNN_DataScience.py'>

# %% [markdown]
# #####  instanciation du modèle **RNN_STEMMER**

# %%
stem = rnn.RNN_STEMMER("EMBEDDING STEMMER")
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# #### **RNN_STEMMER** : Lancement de l'entrainement
# Récupération des Poids du Modèle, des précisions, des pertes et des prédictions.

# %%
# entrainement du modèle
train_acc,val_acc,tloss,tvalloss = stem.fit_modele(5,True,stemming=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67932 entries, 83256 to 20596
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67932 non-null  int64
#  1   designation     67932 non-null  object
#  2   description     44084 non-null  object
#  3   productid       67932 non-null  int64
#  4   imageid         67932 non-null  int64
#  5   PAYS_LANGUE     67932 non-null  object
#  6   RATIO_LANGUE    67932 non-null  float64
#  7   ORIGINE_LANGUE  67932 non-null  object
#  8   pays_design     67932 non-null  object
#  9   Ratio_design    67932 non-null  float64
#  10  pays_descr      44033 non-null  object
#  11  Ratio_descr     44033 non-null  float64
#  12  descr_NaN       67932 non-null  bool
#  13  nom_image       67932 non-null  object
#  14  filepath        67932 non-null  object
#  15  phrases         67932 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(9)
# memory usage: 8.4+ MB
# None
# etape 1/6
# etape 2/6
# etape 3/6
# save y_train_avant.shape  (67932,)
# self.EMBEDDING_DIM 300
# suite
# (67932, 27)
# (16984, 27)
# vocab_size :  112086
# Epoch 1/5
# 2123/2123 [==============================] - 1680s 790ms/step - loss: 1.1424 - accuracy: 0.6714 - val_loss: 0.7287 - val_accuracy: 0.7922 - lr: 0.0010
# Epoch 2/5
# 2123/2123 [==============================] - 1607s 757ms/step - loss: 0.4548 - accuracy: 0.8675 - val_loss: 0.6938 - val_accuracy: 0.8139 - lr: 0.0010
# Epoch 3/5
# 2123/2123 [==============================] - 1615s 761ms/step - loss: 0.2382 - accuracy: 0.9311 - val_loss: 0.7906 - val_accuracy: 0.8068 - lr: 0.0010
# Epoch 4/5
# 2123/2123 [==============================] - 1609s 758ms/step - loss: 0.1332 - accuracy: 0.9608 - val_loss: 0.9150 - val_accuracy: 0.8037 - lr: 0.0010
# Epoch 5/5
# 2123/2123 [==============================] - 1608s 758ms/step - loss: 0.0955 - accuracy: 0.9725 - val_loss: 1.0060 - val_accuracy: 0.8059 - lr: 0.0010
# 531/531 [==============================] - 63s 117ms/step
# 2123/2123 [==============================] - 253s 119ms/step
# 531/531 [==============================] - 65s 122ms/step
# y_test_original2[:5]  [1301 1140 2583 2280 2403]

# %% [markdown]
# #### **RNN_STEMMER** : Optionnel : Récupération des données

# %%
# RECUPERATION
"""
train_acc,val_acc,tloss,tvalloss = stem.restore_fit_arrays()
y_orig,y_pred = stem.restore_predict_arrays()
df_pred = stem.restore_predict_dataframe()

"""

# %% [markdown]
# #### **RNN_STEMMER** : Affichage des precisions et des pertes par époque

# %%
ds.plot_fit(train_acc,val_acc,tloss,tvalloss)

# %% [markdown]
# #### **RNN_STEMMER** : Affichage des 3 principales prédictions par catégorie
# Tableau des repartitions des **classes prédites** pour chaque **classe réelle**

# %%
df_pred = stem.get_df_pred()
df_pred
# Out:
#     Categorie  predict     pourc  predict2    pourc2  predict3    pourc3
# 0          10       10  0.306581      2403  0.189406      2705  0.166934
# 1          40       40  0.745020        50  0.039841      1280  0.033865
# 2          50       50  0.818452        40  0.050595      2462  0.050595
# 3          60       60  0.903614        50  0.042169      2462  0.024096
# 4        1140     1140  0.676030      1280  0.108614        40  0.035581
# 5        1160     1160  0.858407        40  0.036662      2705  0.022756
# 6        1180     1180  0.627451        40  0.071895      1280  0.058824
# 7        1280     1280  0.757700      1281  0.047228      1140  0.041068
# 8        1281     1281  0.466184      1280  0.212560        40  0.053140
# 9        1300     1300  0.941526      1280  0.020813      2280  0.005946
# 10       1301     1301  0.906832      1280  0.018634      1302  0.018634
# 11       1302     1302  0.799197      1280  0.058233      2583  0.032129
# 12       1320     1320  0.756173      1280  0.050926      1920  0.032407
# 13       1560     1560  0.830542      2582  0.048276      2060  0.036453
# 14       1920     1920  0.921022      2060  0.025552      1560  0.024390
# 15       1940     1940  0.813665      2060  0.024845      2280  0.024845
# 16       2060     2060  0.797798      1560  0.056056      1920  0.029029
# 17       2220     2220  0.751515      1320  0.048485        50  0.024242
# 18       2280     2280  0.822479      2403  0.097689        10  0.023109
# 19       2403     2403  0.773822      2280  0.074346        10  0.048168
# 20       2462     2462  0.700704        40  0.105634        60  0.070423
# 21       2522     2522  0.928858      2403  0.015030      1560  0.010020
# 22       2582     2582  0.754826      2060  0.067568      1560  0.044402
# 23       2583     2583  0.980901      1302  0.005387      2060  0.003918
# 24       2585     2585  0.739479      2583  0.056112      2582  0.052104
# 25       2705     2705  0.679348      2403  0.096014        10  0.090580
# 26       2905     2905  0.994253      2583  0.005747      1920  0.000000

# %% [markdown]
# #### **RNN_STEMMER** : Rapport de classification
# Ce rapport inclut des métriques comme la précision, le rappel (recall), le score F1 et le support pour chaque classe individuelle :
#
# 1. Précision (**Precision**) : Le ratio des prédictions correctes pour chaque classe par rapport à toutes les prédictions faites pour cette classe.
# 2. Rappel (**Recall**) : Le ratio des prédictions correctes pour chaque classe par rapport au nombre total d'instances réelles de cette classe.
# 3. **Score F1** : La moyenne harmonique de la précision et du rappel, fournissant une mesure unique de la performance qui équilibre les deux.
# 4. **Support** : Le nombre d'occurrences réelles de chaque classe dans l'ensemble de test.

# %%
#y_orig = ds.load_ndarray('EMBEDDING STEMMER_y_orig')
#y_pred = ds.load_ndarray('EMBEDDING STEMMER_y_pred')
y_orig = stem.get_y_orig()
y_pred = stem.get_y_pred()
_,_ = ds.get_classification_report(y_orig, y_pred)
# Out:
# Précision de la prédiction: 80.59349976448422 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.55      0.31      0.39       623
#           40       0.55      0.75      0.63       502
#           50       0.76      0.82      0.79       336
#           60       0.74      0.90      0.81       166
#         1140       0.80      0.68      0.73       534
#         1160       0.90      0.86      0.88       791
#         1180       0.55      0.63      0.59       153
#         1280       0.68      0.76      0.72       974
#         1281       0.65      0.47      0.54       414
#         1300       0.94      0.94      0.94      1009
#         1301       0.90      0.91      0.90       161
#         1302       0.85      0.80      0.82       498
#         1320       0.87      0.76      0.81       648
#         1560       0.84      0.83      0.84      1015
#         1920       0.90      0.92      0.91       861
#         1940       0.83      0.81      0.82       161
#         2060       0.82      0.80      0.81       999
#         2220       0.77      0.75      0.76       165
#         2280       0.80      0.82      0.81       952
#         2403       0.68      0.77      0.72       955
#         2462       0.79      0.70      0.74       284
#         2522       0.86      0.93      0.89       998
#         2582       0.75      0.75      0.75       518
#         2583       0.95      0.98      0.97      2042
#         2585       0.87      0.74      0.80       499
#         2705       0.61      0.68      0.64       552
#         2905       0.98      0.99      0.99       174
#
#     accuracy                           0.81     16984
#    macro avg       0.78      0.78      0.78     16984
# weighted avg       0.81      0.81      0.80     16984

# %% [markdown]
# #### **RNN_STEMMER** : Génération et Affichage de la Matrice de Confusion
# 1. La **matrice de confusion** fournit une représentation visuelle des performances du modèle, montrant non seulement les bonnes classifications
# mais aussi les erreurs (**faux positifs** et **faux négatifs**).
# 2. En identifiant où le modèle a échoué (c.-à-d., les cellules non-diagonales de la matrice), on peut cibler les améliorations à apporter
# au modèle ou aux données d'entraînement.
# 3. Analyser la matrice de confusion permet d'identifier des classes spécifiques qui sont souvent confondues, ce qui peut indiquer un besoin d'ajustement des caractéristiques d'entrée ou d'ajout de données supplémentaires pour ces classes.

# %%
ds.show_confusion_matrix(y_orig, y_pred)

# %% [markdown]
# ### ETAPE 4.2 : La Lemmatisation
# La lemmatisation, qui prend en considération le contexte dans lequel le mot est écrit, a pour but de trouver la forme canonique du mot, le lemme. Par conséquent, elle doit se faire après la transformation des lettres majuscules en minuscules et avant la tokenisation car les mots présents avant et après sont importants pour déterminer la nature du mot.
# Le lemme correspond à l’infinitif des verbes et à la forme au masculin singulier des noms, adjectifs et articles. Par exemple cette méthode est capable de faire la différence entre “nous avions” : verbe avoir et “les avions” : le pluriel d’un avion.

# %% [markdown]
# # Modèle 3 : classe RNN_LEMMER
#
# ### Une tokenisation puis une lemmatisation en utilisant NLTK suivie d'une couche d'Embedding de tensorFlow
# EMBEDDING + LEMMISATION

# %% [markdown]
# #####  instanciation du modèle **RNN_LEMMER**

# %%
lem = rnn.RNN_LEMMER("EMBEDDING LEMMER")
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# #### **RNN_LEMMER** : Lancement de l'entrainement
# Récupération des Poids du Modèle, des précisions, des pertes et des prédictions.

# %%
# entrainement du modèle
train_acc,val_acc,tloss,tvalloss = lem.fit_modele(5,True,lemming=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67932 entries, 83256 to 20596
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67932 non-null  int64
#  1   designation     67932 non-null  object
#  2   description     44084 non-null  object
#  3   productid       67932 non-null  int64
#  4   imageid         67932 non-null  int64
#  5   PAYS_LANGUE     67932 non-null  object
#  6   RATIO_LANGUE    67932 non-null  float64
#  7   ORIGINE_LANGUE  67932 non-null  object
#  8   pays_design     67932 non-null  object
#  9   Ratio_design    67932 non-null  float64
#  10  pays_descr      44033 non-null  object
#  11  Ratio_descr     44033 non-null  float64
#  12  descr_NaN       67932 non-null  bool
#  13  nom_image       67932 non-null  object
#  14  filepath        67932 non-null  object
#  15  phrases         67932 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(9)
# memory usage: 8.4+ MB
# None
# etape 1/6
# etape 2/6
# etape 3/6
# save y_train_avant.shape  (67932,)
# self.EMBEDDING_DIM 300
# suite
# (67932, 27)
# (16984, 27)
# vocab_size :  112086
# Epoch 1/5
# 2123/2123 [==============================] - 1802s 848ms/step - loss: 1.1214 - accuracy: 0.6749 - val_loss: 0.7337 - val_accuracy: 0.7908 - lr: 0.0010
# Epoch 2/5
# 2123/2123 [==============================] - 1785s 841ms/step - loss: 0.4579 - accuracy: 0.8673 - val_loss: 0.7026 - val_accuracy: 0.8066 - lr: 0.0010
# Epoch 3/5
# 2123/2123 [==============================] - 1792s 844ms/step - loss: 0.2357 - accuracy: 0.9307 - val_loss: 0.8267 - val_accuracy: 0.8041 - lr: 0.0010
# Epoch 4/5
# 2123/2123 [==============================] - 1795s 846ms/step - loss: 0.1378 - accuracy: 0.9606 - val_loss: 0.8843 - val_accuracy: 0.8115 - lr: 0.0010
# Epoch 5/5
# 2123/2123 [==============================] - 1811s 853ms/step - loss: 0.0930 - accuracy: 0.9732 - val_loss: 1.0278 - val_accuracy: 0.8060 - lr: 0.0010
# 531/531 [==============================] - 78s 145ms/step
# 2123/2123 [==============================] - 311s 146ms/step
# 531/531 [==============================] - 76s 144ms/step
# y_test_original2[:5]  [1301 1140 2583 2280 2403]

# %% [markdown]
# #### **RNN_LEMMER** : Optionnel : Récupération des données

# %%
# RECUPERATION
"""
train_acc,val_acc,tloss,tvalloss = lem.restore_fit_arrays()
y_orig,y_pred = lem.restore_predict_arrays()
df_pred = lem.restore_predict_dataframe()

"""

# %% [markdown]
# #### **RNN_LEMMER** : Affichage des precisions et des pertes par époque

# %%
ds.plot_fit(train_acc,val_acc,tloss,tvalloss)

# %% [markdown]
# #### **RNN_LEMMER** : Affichage des 3 principales prédictions par catégorie
# Tableau des repartitions des **classes prédites** pour chaque **classe réelle**

# %%
df_pred = lem.get_df_pred()
df_pred
# Out:
#     Categorie  predict     pourc  predict2    pourc2  predict3    pourc3
# 0          10       10  0.627608      2705  0.113965      2280  0.060995
# 1          40       40  0.701195        10  0.073705      2462  0.043825
# 2          50       50  0.770833      2462  0.065476        40  0.050595
# 3          60       60  0.855422      2462  0.072289        50  0.030120
# 4        1140     1140  0.732210      1280  0.069288        40  0.037453
# 5        1160     1160  0.859671        10  0.058154        40  0.020228
# 6        1180     1180  0.529412        10  0.065359      1140  0.065359
# 7        1280     1280  0.642710      1281  0.124230      1140  0.065708
# 8        1281     1281  0.606280      1280  0.082126        40  0.045894
# 9        1300     1300  0.903865      1280  0.029732      1140  0.009911
# 10       1301     1301  0.900621      1320  0.024845      1281  0.018634
# 11       1302     1302  0.831325      1281  0.030120      2583  0.024096
# 12       1320     1320  0.820988      1560  0.024691      2060  0.024691
# 13       1560     1560  0.838424      2582  0.044335      2060  0.041379
# 14       1920     1920  0.911731      2060  0.031359      1560  0.020906
# 15       1940     1940  0.782609        10  0.043478      1320  0.024845
# 16       2060     2060  0.799800      1560  0.070070      1920  0.024024
# 17       2220     2220  0.678788      2060  0.078788      2585  0.048485
# 18       2280     2280  0.789916        10  0.117647      2403  0.052521
# 19       2403     2403  0.678534        10  0.160209      2280  0.072251
# 20       2462     2462  0.707746        40  0.102113        50  0.049296
# 21       2522     2522  0.898798      1560  0.020040      2403  0.013026
# 22       2582     2582  0.743243      2060  0.067568      2585  0.063707
# 23       2583     2583  0.977473      1302  0.004897      2585  0.003428
# 24       2585     2585  0.807615      2582  0.048096      1560  0.028056
# 25       2705     2705  0.695652        10  0.215580      2403  0.025362
# 26       2905     2905  1.000000      1920  0.000000      2705  0.000000

# %% [markdown]
# #### **RNN_LEMMER** : Rapport de classification
# Ce rapport inclut des métriques comme la précision, le rappel (recall), le score F1 et le support pour chaque classe individuelle :
#
# 1. Précision (**Precision**) : Le ratio des prédictions correctes pour chaque classe par rapport à toutes les prédictions faites pour cette classe.
# 2. Rappel (**Recall**) : Le ratio des prédictions correctes pour chaque classe par rapport au nombre total d'instances réelles de cette classe.
# 3. **Score F1** : La moyenne harmonique de la précision et du rappel, fournissant une mesure unique de la performance qui équilibre les deux.
# 4. **Support** : Le nombre d'occurrences réelles de chaque classe dans l'ensemble de test.

# %%
y_orig = lem.get_y_orig()
y_pred = lem.get_y_pred()
_,_ = ds.get_classification_report(y_orig, y_pred)
# Out:
# Précision de la prédiction: 80.59938765897316 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.41      0.63      0.49       623
#           40       0.64      0.70      0.67       502
#           50       0.82      0.77      0.79       336
#           60       0.87      0.86      0.86       166
#         1140       0.69      0.73      0.71       534
#         1160       0.89      0.86      0.87       791
#         1180       0.65      0.53      0.58       153
#         1280       0.76      0.64      0.70       974
#         1281       0.51      0.61      0.55       414
#         1300       0.99      0.90      0.94      1009
#         1301       0.96      0.90      0.93       161
#         1302       0.76      0.83      0.79       498
#         1320       0.80      0.82      0.81       648
#         1560       0.82      0.84      0.83      1015
#         1920       0.91      0.91      0.91       861
#         1940       0.85      0.78      0.82       161
#         2060       0.81      0.80      0.81       999
#         2220       0.88      0.68      0.77       165
#         2280       0.84      0.79      0.82       952
#         2403       0.82      0.68      0.74       955
#         2462       0.71      0.71      0.71       284
#         2522       0.94      0.90      0.92       998
#         2582       0.75      0.74      0.75       518
#         2583       0.96      0.98      0.97      2042
#         2585       0.77      0.81      0.79       499
#         2705       0.69      0.70      0.69       552
#         2905       0.93      1.00      0.96       174
#
#     accuracy                           0.81     16984
#    macro avg       0.79      0.78      0.78     16984
# weighted avg       0.82      0.81      0.81     16984

# %% [markdown]
# #### **RNN_LEMMER** : Génération et Affichage de la Matrice de Confusion
# 1. La **matrice de confusion** fournit une représentation visuelle des performances du modèle, montrant non seulement les bonnes classifications
# mais aussi les erreurs (**faux positifs** et **faux négatifs**).
# 2. En identifiant où le modèle a échoué (c.-à-d., les cellules non-diagonales de la matrice), on peut cibler les améliorations à apporter
# au modèle ou aux données d'entraînement.
# 3. Analyser la matrice de confusion permet d'identifier des classes spécifiques qui sont souvent confondues, ce qui peut indiquer un besoin d'ajustement des caractéristiques d'entrée ou d'ajout de données supplémentaires pour ces classes.

# %%
ds.show_confusion_matrix(y_orig, y_pred)

# %% [markdown]
# # Modèle 4 : classe RNN_SPACY
#
# ### Une tokenisation puis une lemmatisation en utilisant SPACY suivie d'une couche d'Embedding de tensorFlow
# EMBEDDING + SPACY

# %%
import Bibli_DataScience_3_3 as ds
import RNN_DataScience as rnn
import imp
imp.reload(ds)
imp.reload(rnn)
# Out:
# section :  ['DOSSIER', 'FICHIER']
# <module 'RNN_DataScience' from '/content/Rakuten_Text_Classification_TensorFlow/src/RNN_DataScience.py'>

# %% [markdown]
# #####  instanciation du modèle **RNN_SPACY**

# %%
spacy = rnn.RNN_SPACY("EMBEDDING SPACY")
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# #### **RNN_SPACY** : Lancement de l'entrainement
# Récupération des Poids du Modèle, des précisions, des pertes et des prédictions.

# %%
# entrainement du modèle
train_acc,val_acc,tloss,tvalloss = spacy.fit_modele(5,True,spacy=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67932 entries, 83256 to 20596
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67932 non-null  int64
#  1   designation     67932 non-null  object
#  2   description     44084 non-null  object
#  3   productid       67932 non-null  int64
#  4   imageid         67932 non-null  int64
#  5   PAYS_LANGUE     67932 non-null  object
#  6   RATIO_LANGUE    67932 non-null  float64
#  7   ORIGINE_LANGUE  67932 non-null  object
#  8   pays_design     67932 non-null  object
#  9   Ratio_design    67932 non-null  float64
#  10  pays_descr      44033 non-null  object
#  11  Ratio_descr     44033 non-null  float64
#  12  descr_NaN       67932 non-null  bool
#  13  nom_image       67932 non-null  object
#  14  filepath        67932 non-null  object
#  15  phrases         67932 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(9)
# memory usage: 8.4+ MB
# None
# etape 1/6
# etape 2/6
# etape 3/6
# save y_train_avant.shape  (67932,)
# self.EMBEDDING_DIM 300
# suite
# (67932, 27)
# (16984, 27)
# etape 4/6
# etape 5/6
# etape 6/6
# vocab_size :  111846
# output :  300
# vocab_size =  111846
# Epoch 1/5
# 2123/2123 [==============================] - 1848s 869ms/step - loss: 1.1225 - accuracy: 0.6769 - val_loss: 0.7559 - val_accuracy: 0.7773 - lr: 0.0010
# Epoch 2/5
# 2123/2123 [==============================] - 1850s 872ms/step - loss: 0.4418 - accuracy: 0.8719 - val_loss: 0.6675 - val_accuracy: 0.8104 - lr: 0.0010
# Epoch 3/5
# 2123/2123 [==============================] - 1852s 872ms/step - loss: 0.2220 - accuracy: 0.9363 - val_loss: 0.8601 - val_accuracy: 0.7979 - lr: 0.0010
# Epoch 4/5
# 2123/2123 [==============================] - 1845s 869ms/step - loss: 0.1344 - accuracy: 0.9624 - val_loss: 0.9159 - val_accuracy: 0.8035 - lr: 0.0010
# Epoch 5/5
# 2123/2123 [==============================] - 1847s 870ms/step - loss: 0.0886 - accuracy: 0.9749 - val_loss: 1.0275 - val_accuracy: 0.8028 - lr: 0.0010
# 531/531 [==============================] - 78s 146ms/step
# 2123/2123 [==============================] - 309s 146ms/step
# 531/531 [==============================] - 77s 145ms/step
# y_test_original2[:5]  [1301 1140 2583 2280 2403]

# %% [markdown]
# #### **RNN_SPACY** : Optionnel : Récupération des données

# %%
# RECUPERATION
"""
train_acc,val_acc,tloss,tvalloss = spacy.restore_fit_arrays()
y_orig,y_pred = spacy.restore_predict_arrays()
df_pred = spacy.restore_predict_dataframe()

"""

# %% [markdown]
# #### **RNN_SPACY** : Affichage des precisions et des pertes par époque

# %%
ds.plot_fit(train_acc,val_acc,tloss,tvalloss)

# %% [markdown]
# #### **RNN_SPACY** : Affichage des 3 principales prédictions par catégorie
# Tableau des repartitions des **classes prédites** pour chaque **classe réelle**

# %%
df_pred = spacy.get_df_pred()
df_pred
# Out:
#     Categorie  predict     pourc  predict2    pourc2  predict3    pourc3
# 0          10       10  0.600321      2705  0.110754      2403  0.072231
# 1          40       40  0.645418      1140  0.057769      2462  0.051793
# 2          50       50  0.747024      2462  0.068452      1140  0.050595
# 3          60       60  0.789157      2462  0.090361        50  0.072289
# 4        1140     1140  0.784644      1280  0.073034      1180  0.028090
# 5        1160     1160  0.867257        10  0.032870      1140  0.030341
# 6        1180     1180  0.594771      1140  0.117647        10  0.065359
# 7        1280     1280  0.723819      1281  0.074949      1140  0.070842
# 8        1281     1281  0.550725      1280  0.135266      1302  0.043478
# 9        1300     1300  0.917740      1280  0.031715      1140  0.011893
# 10       1301     1301  0.869565      1280  0.024845      1320  0.024845
# 11       1302     1302  0.825301      1280  0.036145      2583  0.028112
# 12       1320     1320  0.816358      1280  0.037037      1560  0.020062
# 13       1560     1560  0.855172      2582  0.039409      2060  0.020690
# 14       1920     1920  0.867596      1560  0.058072      1320  0.023229
# 15       1940     1940  0.801242        10  0.037267      1320  0.031056
# 16       2060     2060  0.694695      1560  0.114114      1320  0.037037
# 17       2220     2220  0.812121      1320  0.042424      2583  0.024242
# 18       2280     2280  0.817227        10  0.090336      2403  0.055672
# 19       2403     2403  0.712042        10  0.114136      2280  0.074346
# 20       2462     2462  0.735915        40  0.070423        50  0.049296
# 21       2522     2522  0.892786      1560  0.026052      2403  0.025050
# 22       2582     2582  0.725869      1560  0.098456      2585  0.044402
# 23       2583     2583  0.978942      1302  0.007346      1320  0.002938
# 24       2585     2585  0.753507      2583  0.050100      2582  0.046092
# 25       2705     2705  0.666667        10  0.215580      2403  0.030797
# 26       2905     2905  0.982759      1180  0.005747      1281  0.005747

# %% [markdown]
# #### **RNN_SPACY** : Rapport de classification
# Ce rapport inclut des métriques comme la précision, le rappel (recall), le score F1 et le support pour chaque classe individuelle :
#
# 1. Précision (**Precision**) : Le ratio des prédictions correctes pour chaque classe par rapport à toutes les prédictions faites pour cette classe.
# 2. Rappel (**Recall**) : Le ratio des prédictions correctes pour chaque classe par rapport au nombre total d'instances réelles de cette classe.
# 3. **Score F1** : La moyenne harmonique de la précision et du rappel, fournissant une mesure unique de la performance qui équilibre les deux.
# 4. **Support** : Le nombre d'occurrences réelles de chaque classe dans l'ensemble de test.

# %%
y_orig = spacy.get_y_orig()
y_pred = spacy.get_y_pred()
_,_ = ds.get_classification_report(y_orig, y_pred)
# Out:
# Précision de la prédiction: 80.2814413565709 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.45      0.60      0.51       623
#           40       0.72      0.65      0.68       502
#           50       0.81      0.75      0.78       336
#           60       0.96      0.79      0.86       166
#         1140       0.58      0.78      0.67       534
#         1160       0.88      0.87      0.87       791
#         1180       0.51      0.59      0.55       153
#         1280       0.71      0.72      0.72       974
#         1281       0.60      0.55      0.57       414
#         1300       0.98      0.92      0.95      1009
#         1301       0.95      0.87      0.91       161
#         1302       0.74      0.83      0.78       498
#         1320       0.77      0.82      0.79       648
#         1560       0.74      0.86      0.80      1015
#         1920       0.94      0.87      0.90       861
#         1940       0.87      0.80      0.83       161
#         2060       0.89      0.69      0.78       999
#         2220       0.69      0.81      0.75       165
#         2280       0.84      0.82      0.83       952
#         2403       0.78      0.71      0.74       955
#         2462       0.71      0.74      0.72       284
#         2522       0.93      0.89      0.91       998
#         2582       0.79      0.73      0.76       518
#         2583       0.96      0.98      0.97      2042
#         2585       0.82      0.75      0.78       499
#         2705       0.68      0.67      0.67       552
#         2905       0.99      0.98      0.99       174
#
#     accuracy                           0.80     16984
#    macro avg       0.79      0.78      0.78     16984
# weighted avg       0.81      0.80      0.81     16984

# %% [markdown]
# #### **RNN_SPACY** : Génération et Affichage de la Matrice de Confusion
# 1. La **matrice de confusion** fournit une représentation visuelle des performances du modèle, montrant non seulement les bonnes classifications
# mais aussi les erreurs (**faux positifs** et **faux négatifs**).
# 2. En identifiant où le modèle a échoué (c.-à-d., les cellules non-diagonales de la matrice), on peut cibler les améliorations à apporter
# au modèle ou aux données d'entraînement.
# 3. Analyser la matrice de confusion permet d'identifier des classes spécifiques qui sont souvent confondues, ce qui peut indiquer un besoin d'ajustement des caractéristiques d'entrée ou d'ajout de données supplémentaires pour ces classes.

# %%
ds.show_confusion_matrix(y_orig, y_pred)

# %%
# Modèle 5 : classe RNN_GRU

# %%
import Bibli_DataScience_3_3 as ds
import RNN_DataScience as rnn
import imp
imp.reload(ds)
imp.reload(rnn)
# Out:
# section :  ['DOSSIER', 'FICHIER']
# <module 'RNN_DataScience' from '/content/Rakuten_Text_Classification_TensorFlow/src/RNN_DataScience.py'>

# %%
#####  instanciation du modèle **RNN_GRU**

# %%
gru =  rnn.RNN_GRU("EMBEDDING GRU")
# Out:
# Pandas Apply:   0%|          | 0/84916 [00:00<?, ?it/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
#### **RNN_GRU ** : Lancement de l'entrainement
Récupération des Poids du Modèle, des précisions, des pertes et des prédictions.

# %%
# entrainement du modèle
train_acc,val_acc,tloss,tvalloss = gru.fit_modele(3,savefics=True,Train='Save')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67932 entries, 83256 to 20596
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67932 non-null  int64
#  1   designation     67932 non-null  object
#  2   description     44084 non-null  object
#  3   productid       67932 non-null  int64
#  4   imageid         67932 non-null  int64
#  5   PAYS_LANGUE     67932 non-null  object
#  6   RATIO_LANGUE    67932 non-null  float64
#  7   ORIGINE_LANGUE  67932 non-null  object
#  8   pays_design     67932 non-null  object
#  9   Ratio_design    67932 non-null  float64
#  10  pays_descr      44033 non-null  object
#  11  Ratio_descr     44033 non-null  float64
#  12  descr_NaN       67932 non-null  bool
#  13  nom_image       67932 non-null  object
#  14  filepath        67932 non-null  object
#  15  phrases         67932 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(9)
# memory usage: 8.4+ MB
# None
# etape 1/6
# etape 2/6
# etape 3/6
# Sauvegarde de jeu d'entrainement
# save y_train_avant.shape  (67932,)
# self.EMBEDDING_DIM 300
# suite
# (67932, 27)
# (16984, 27)
# vocab_size :  112071
# NUM_WORDS 70000
# EMBEDDING_DIM 300
# Sauvegarde de jeu pour la concatenation
# Epoch 1/3
# 2123/2123 [==============================] - 1052s 495ms/step - loss: 1.4422 - accuracy: 0.5822 - val_loss: 0.7661 - val_accuracy: 0.7829 - lr: 0.0010
# Epoch 2/3
# 2123/2123 [==============================] - 1050s 495ms/step - loss: 0.5750 - accuracy: 0.8329 - val_loss: 0.6665 - val_accuracy: 0.8128 - lr: 0.0010
# Epoch 3/3
# 2123/2123 [==============================] - 1054s 496ms/step - loss: 0.3293 - accuracy: 0.9030 - val_loss: 0.7326 - val_accuracy: 0.8126 - lr: 0.0010
# 531/531 [==============================] - 56s 105ms/step
# 2123/2123 [==============================] - 224s 106ms/step
# 531/531 [==============================] - 56s 105ms/step
# Sauvegarde de jeu pour la concatenation
# Sauvegarde de jeu du label encoder
# Sauvegarde du model
# EMBEDDING GRU_weight
# /content/Rakuten_Text_Classification_TensorFlow/input/EMBEDDING GRU_weight.h5
# Sauvegarde du tokenizer
# y_test_original2[:5]  [1301 1140 2583 2280 2403]
# Sauvegarde de jeu du label encoder
# EMBEDDING GRU_weight
# /content/Rakuten_Text_Classification_TensorFlow/input/EMBEDDING GRU_weight.h5

# %%
#### **RNN_GRU** : Affichage des precisions et des pertes par époque

# %%
ds.plot_fit(train_acc,val_acc,tloss,tvalloss)

# %%
#### **RNN_GRU** : Affichage des 3 principales prédictions par catégorie
Tableau des repartitions des **classes prédites** pour chaque **classe réelle**

# %%
df_pred = gru.get_df_pred()
df_pred
# Out:
#     Categorie  predict     pourc  predict2    pourc2  predict3    pourc3
# 0          10       10  0.486356      2403  0.110754      2705  0.093098
# 1          40       40  0.699203      1160  0.049801        10  0.047809
# 2          50       50  0.818452      2462  0.053571        40  0.047619
# 3          60       60  0.789157      2462  0.126506        50  0.054217
# 4        1140     1140  0.694757      1280  0.132959        10  0.022472
# 5        1160     1160  0.897598        40  0.032870        10  0.020228
# 6        1180     1180  0.535948      1280  0.084967      1281  0.078431
# 7        1280     1280  0.755647      1281  0.040041      1140  0.039014
# 8        1281     1281  0.507246      1280  0.200483        40  0.070048
# 9        1300     1300  0.937562      1280  0.021804      1140  0.005946
# 10       1301     1301  0.900621      1180  0.018634        50  0.012422
# 11       1302     1302  0.795181      1280  0.062249      1281  0.030120
# 12       1320     1320  0.779321      2060  0.046296      1280  0.041667
# 13       1560     1560  0.828571      2060  0.055172      2582  0.040394
# 14       1920     1920  0.916376      2060  0.030197      1560  0.025552
# 15       1940     1940  0.726708        10  0.080745      2582  0.049689
# 16       2060     2060  0.845846      1560  0.047047      1280  0.015015
# 17       2220     2220  0.684848      2582  0.060606      1280  0.042424
# 18       2280     2280  0.847689      2403  0.056723        10  0.044118
# 19       2403     2403  0.738220        10  0.097382      2280  0.074346
# 20       2462     2462  0.757042        40  0.070423        50  0.066901
# 21       2522     2522  0.911824      1560  0.016032      2060  0.014028
# 22       2582     2582  0.727799      2585  0.075290      2060  0.071429
# 23       2583     2583  0.979432      2060  0.004897      2585  0.002938
# 24       2585     2585  0.793587      2060  0.048096      1560  0.044088
# 25       2705     2705  0.644928        10  0.206522      2403  0.048913
# 26       2905     2905  0.971264      1301  0.011494      2220  0.005747

# %%
#### **RNN_GRU** : Rapport de classification
Ce rapport inclut des métriques comme la précision, le rappel (recall), le score F1 et le support pour chaque classe individuelle :

1. Précision (**Precision**) : Le ratio des prédictions correctes pour chaque classe par rapport à toutes les prédictions faites pour cette classe.
2. Rappel (**Recall**) : Le ratio des prédictions correctes pour chaque classe par rapport au nombre total d'instances réelles de cette classe.
3. **Score F1** : La moyenne harmonique de la précision et du rappel, fournissant une mesure unique de la performance qui équilibre les deux.
4. **Support** : Le nombre d'occurrences réelles de chaque classe dans l'ensemble de test.

# %%
y_orig = gru.get_y_orig()
y_pred = gru.get_y_pred()
_,_ = ds.get_classification_report(y_orig, y_pred)
# Out:
# Précision de la prédiction: 81.2588318417334 %
# Evaluation détaillée de la Classification par RDF :
#
#                precision    recall  f1-score   support
#
#           10       0.44      0.49      0.46       623
#           40       0.63      0.70      0.66       502
#           50       0.80      0.82      0.81       336
#           60       0.96      0.79      0.87       166
#         1140       0.74      0.69      0.72       534
#         1160       0.82      0.90      0.86       791
#         1180       0.69      0.54      0.60       153
#         1280       0.69      0.76      0.72       974
#         1281       0.65      0.51      0.57       414
#         1300       0.96      0.94      0.95      1009
#         1301       0.88      0.90      0.89       161
#         1302       0.85      0.80      0.82       498
#         1320       0.84      0.78      0.81       648
#         1560       0.81      0.83      0.82      1015
#         1920       0.91      0.92      0.92       861
#         1940       0.85      0.73      0.78       161
#         2060       0.76      0.85      0.80       999
#         2220       0.88      0.68      0.77       165
#         2280       0.83      0.85      0.84       952
#         2403       0.77      0.74      0.75       955
#         2462       0.70      0.76      0.73       284
#         2522       0.92      0.91      0.92       998
#         2582       0.78      0.73      0.75       518
#         2583       0.97      0.98      0.97      2042
#         2585       0.78      0.79      0.79       499
#         2705       0.74      0.64      0.69       552
#         2905       0.99      0.97      0.98       174
#
#     accuracy                           0.81     16984
#    macro avg       0.80      0.78      0.79     16984
# weighted avg       0.81      0.81      0.81     16984

# %%
#### **RNN_GRU** : Génération et Affichage de la Matrice de Confusion
1. La **matrice de confusion** fournit une représentation visuelle des performances du modèle, montrant non seulement les bonnes classifications
mais aussi les erreurs (**faux positifs** et **faux négatifs**).
2. En identifiant où le modèle a échoué (c.-à-d., les cellules non-diagonales de la matrice), on peut cibler les améliorations à apporter
au modèle ou aux données d'entraînement.
3. Analyser la matrice de confusion permet d'identifier des classes spécifiques qui sont souvent confondues, ce qui peut indiquer un besoin d'ajustement des caractéristiques d'entrée ou d'ajout de données supplémentaires pour ces classes.

# %%
ds.show_confusion_matrix(y_orig, y_pred)
